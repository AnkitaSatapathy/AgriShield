# %% [markdown]
# # Government Schemes Recommendation System 2026 - Expanded Edition
#
# This notebook processes **67 government agricultural schemes** from across India (2026) and provides:
# - Personalized scheme recommendations
# - Comprehensive crop descriptions
# - Detailed growing tips for each crop type
# - Coverage of all states and union territories
#
# **New Features:**
# - 34 additional state-specific schemes
# - Union Territory schemes included
# - Technology schemes (AI, drones, solar)
# - Sustainability initiatives
# - Specialty crops coverage

# %% [markdown]
# ## 1. Import Libraries and Load Data

# %%
import pandas as pd
import os
print('✅ Ready to load schemes!')
# Out:
# ✅ Ready to load schemes!

# %%
schemes_data = [
    {
        'scheme_id': 'PM_KISAN_001',
        'scheme_name': 'PM-KISAN (Pradhan Mantri Kisan Samman Nidhi)',
        'description': 'Income support of ₹6000 per year in three equal installments to all landholding farmer families',
        'benefits': '₹6000/year in 3 installments of ₹2000 each, Direct benefit transfer to bank account',
        'eligibility_criteria': 'Landholding farmer families, All states except Assam, Meghalaya, J&K, Ladakh initially',
        'documents_required': 'Aadhaar card, Bank account details, Land ownership documents, Self-declaration form',
        'application_link': 'https://pmkisan.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Financial Support'
    },
    {
        'scheme_id': 'PMFBY_001',
        'scheme_name': 'PMFBY (Pradhan Mantri Fasal Bima Yojana)',
        'description': 'Crop insurance scheme providing financial support to farmers in case of crop loss',
        'benefits': 'Coverage against crop loss due to natural calamities, pests & diseases. Low premium rates: 2% for Kharif, 1.5% for Rabi, 5% for horticulture',
        'eligibility_criteria': 'All farmers including sharecroppers and tenant farmers, Applicable for notified crops',
        'documents_required': 'Aadhaar card, Bank account details, Land records, Sowing certificate',
        'application_link': 'https://pmfby.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'Rice,Wheat,Cotton,Sugarcane,Pulses,Oilseeds',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Insurance'
    },
    {
        'scheme_id': 'SHC_001',
        'scheme_name': 'Soil Health Card Scheme',
        'description': 'Provides soil health cards to farmers every 2 years with soil nutrient status and fertilizer recommendations',
        'benefits': 'Free soil testing, Customized fertilizer recommendations, Improved soil health management, Reduced input costs',
        'eligibility_criteria': 'All farmers with agricultural land',
        'documents_required': 'Land ownership documents, Aadhaar card, Soil samples',
        'application_link': 'https://soilhealth.dac.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Advisory'
    },
    {
        'scheme_id': 'KCC_001',
        'scheme_name': 'Kisan Credit Card (KCC)',
        'description': 'Credit facility for farmers to meet crop production and related expenses',
        'benefits': 'Credit up to ₹3 lakhs at 7% interest, Additional 3% interest subvention on timely repayment, Flexible repayment terms',
        'eligibility_criteria': 'Individual/joint borrowers who are owner cultivators, Tenant farmers, sharecroppers, oral lessees',
        'documents_required': 'Identity proof, Address proof, Land documents, Passport size photographs',
        'application_link': 'https://www.nabard.org/content1.aspx?id=573&catid=8&mid=489',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Credit'
    },
    {
        'scheme_id': 'PKVY_001',
        'scheme_name': 'PKVY (Paramparagat Krishi Vikas Yojana)',
        'description': 'Promotes organic farming and certification',
        'benefits': '₹50,000/ha for 3 years for cluster formation, Organic inputs, Certification support',
        'eligibility_criteria': 'Farmers willing to adopt organic farming, Group/cluster based approach',
        'documents_required': 'Group formation documents, Land details, Aadhaar card, Bank account',
        'application_link': 'https://pgsindia-ncof.gov.in/PKVY/Index.aspx',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal',
        'scheme_type': 'Subsidy'
    },
    {
        'scheme_id': 'PMKSY_001',
        'scheme_name': 'PMKSY (Pradhan Mantri Krishi Sinchayee Yojana)',
        'description': 'Aims to expand cultivated area with assured irrigation, improve water use efficiency',
        'benefits': 'Subsidy for drip/sprinkler irrigation, Micro-irrigation support, Watershed development',
        'eligibility_criteria': 'Individual farmers, Self-help groups, Community organizations',
        'documents_required': 'Land documents, Aadhaar card, Bank account details, Project proposal',
        'application_link': 'https://pmksy.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'Rice,Wheat,Cotton,Sugarcane,Vegetables,Fruits',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Subsidy'
    },
    {
        'scheme_id': 'NDDS_001',
        'scheme_name': 'Namo Drone Didi Scheme',
        'description': 'Empowering Women Self Help Groups (SHGs) with drones for agricultural rental services',
        'benefits': '80% subsidy (up to ₹8 lakh) for drones, Free drone pilot training, Income generation',
        'eligibility_criteria': 'Women Self Help Groups (SHGs)',
        'documents_required': 'SHG registration documents, Aadhaar cards of members, Bank account details',
        'application_link': 'https://pib.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Technology'
    },
    {
        'scheme_id': 'KSP_001',
        'scheme_name': 'Krishi Sakhi Program',
        'description': 'Training rural women as Para-extension Workers to support farmers with modern agricultural practices',
        'benefits': 'Certification as Krishi Sakhi, Income opportunity as community resource persons, Skill development',
        'eligibility_criteria': 'Women farmers, Rural women interested in agriculture extension',
        'documents_required': 'Aadhaar card, Education certificates (if any), Bank account details',
        'application_link': 'https://pib.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Advisory'
    },
    {
        'scheme_id': 'MKSP_001',
        'scheme_name': 'Mahila Kisan Sashaktikaran Pariyojana (MKSP)',
        'description': 'Empowering women in agriculture through sustainable practices and capacity building',
        'benefits': 'Training in sustainable agriculture, Support for community institutions, Improved access to inputs and markets',
        'eligibility_criteria': 'Women farmers, Mahila Kisans',
        'documents_required': 'Aadhaar card, SHG membership proof (if applicable), Land documents (optional)',
        'application_link': 'https://mksp.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal',
        'scheme_type': 'Financial Support'
    },
    {
        'scheme_id': 'KDS_001',
        'scheme_name': 'Kisan Drone Scheme',
        'description': 'Promoting drone technology for crop assessment, digitization of land records, and spraying',
        'benefits': 'Up to 50% subsidy for individual farmers, 40% for FPOs, 100% for ICAR institutes',
        'eligibility_criteria': 'Farmers, FPOs, Custom Hiring Centers',
        'documents_required': 'Aadhaar card, Land records, FPO registration (for groups)',
        'application_link': 'https://agricoop.nic.in/',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Technology'
    },
    {
        'scheme_id': 'CPP_001',
        'scheme_name': 'Clean Plant Programme (CPP)',
        'description': 'Providing access to disease-free, quality planting material for high-value horticulture crops',
        'benefits': 'Access to certified virus-free planting material, Enhanced crop quality and yield',
        'eligibility_criteria': 'Horticulture farmers, Nurseries',
        'documents_required': 'Land documents, Nursery registration (for nurseries), Aadhaar card',
        'application_link': 'https://nhb.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'Fruits,Vegetables',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Subsidy'
    },
    {
        'scheme_id': 'DAM_001',
        'scheme_name': 'Digital Agriculture Mission',
        'description': 'Building Digital Public Infrastructure for agriculture to provide farmers with real-time data and services',
        'benefits': 'Access to digital services, Real-time weather and market info, Digital identities for farmers',
        'eligibility_criteria': 'All Farmers',
        'documents_required': 'Aadhaar card, Mobile number linked to Aadhaar',
        'application_link': 'https://agricoop.nic.in/',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Technology'
    },
    {
        'scheme_id': 'PMDDKY_001',
        'scheme_name': 'Prime Minister Dhan-Dhaanya Krishi Yojana',
        'description': 'Targeting 100 low-productivity districts to boost yield through modern techniques',
        'benefits': 'Enhanced credit access, Improved irrigation facilities, Modern cultivation technique support',
        'eligibility_criteria': 'Farmers in identified 100 districts',
        'documents_required': 'Land documents, Aadhaar card, Bank account',
        'application_link': 'https://agricoop.nic.in/',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal',
        'scheme_type': 'Financial Support'
    },
    {
        'scheme_id': 'MAP_001',
        'scheme_name': 'Mission for Aatmanirbharta in Pulses',
        'description': 'Aiming for self-sufficiency in pulses production like Tur, Urad, and Masoor',
        'benefits': 'MSP assurance, Seed minikits distribution, Technical support',
        'eligibility_criteria': 'Pulses farmers',
        'documents_required': 'Land documents, Aadhaar card, Bank account',
        'application_link': 'https://nfsm.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'Pulses,Tur,Urad,Masoor',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Subsidy'
    },
    {
        'scheme_id': 'NMEO_001',
        'scheme_name': 'National Mission on Edible Oils (NMEO-OP)',
        'description': 'Promoting oil palm cultivation to reduce import dependency on edible oils',
        'benefits': 'Subsidy on planting material, Maintenance cost support, Intercropping support',
        'eligibility_criteria': 'Farmers in potential states',
        'documents_required': 'Land documents, Aadhaar card, Bank account',
        'application_link': 'https://nmeo.Agricoop.nic.in/',
        'state_applicability': 'All States',
        'crop_types': 'Oilseeds,Oil Palm',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Subsidy'
    },
    {
        'scheme_id': 'SKY_001',
        'scheme_name': 'Samrudha Krushaka Yojana',
        'description': 'Direct financial assistance to paddy farmers to ensure fair prices',
        'benefits': 'Financial assistance, Fair price buying',
        'eligibility_criteria': 'Paddy farmers in Odisha',
        'documents_required': 'Land documents, Aadhaar card, Bank account',
        'application_link': 'https://odisha.gov.in/',
        'state_applicability': 'Odisha',
        'crop_types': 'Paddy',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Financial Support'
    },
    {
        'scheme_id': 'TNAMS_001',
        'scheme_name': 'TN Agricultural Mechanization Scheme',
        'description': 'Subsidy for purchasing farm machinery to mechanize agriculture',
        'benefits': 'Subsidy on tractors, tillers, and other machinery',
        'eligibility_criteria': 'Farmers in Tamil Nadu',
        'documents_required': 'Land documents, Aadhaar card, Bank account',
        'application_link': 'https://aed.tn.gov.in/',
        'state_applicability': 'Tamil Nadu',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Technology'
    },
    {
        'scheme_id': 'RB_001',
        'scheme_name': 'Rythu Bharosa',
        'description': 'Investment support for agriculture and horticulture crops',
        'benefits': 'Financial assistance of ₹10000/acre/year',
        'eligibility_criteria': 'Land owning farmers in Telangana',
        'documents_required': 'Land documents, Aadhaar card, Bank account',
        'application_link': 'https://rythubharosa.telangana.gov.in/',
        'state_applicability': 'Telangana',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Financial Support'
    },
    {
        'scheme_id': 'CMPKC_001',
        'scheme_name': 'Chief Minister Punjab Kissan Card',
        'description': 'Digital card for farmers to access easy credit and subsidies',
        'benefits': 'Easy access to loans, Subsidies on inputs',
        'eligibility_criteria': 'Farmers in Punjab',
        'documents_required': 'Land documents, Aadhaar card, Bank account',
        'application_link': 'https://agri.punjab.gov.in/',
        'state_applicability': 'Punjab',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Credit'
    },
    {
        'scheme_id': 'HCDS_001',
        'scheme_name': 'Crop Diversification Scheme',
        'description': 'Encouraging farmers to shift from paddy to less water-consuming crops',
        'benefits': 'Financial incentive for alternate crops',
        'eligibility_criteria': 'Farmers shifting from paddy in Haryana',
        'documents_required': 'Land documents, Aadhaar card, Bank account',
        'application_link': 'https://agriharyana.gov.in/',
        'state_applicability': 'Haryana',
        'crop_types': 'Maize,Pulses,Oilseeds',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Sustainability'
    },
    {
        'scheme_id': 'MAAP_001',
        'scheme_name': 'MahaAgri-AI Policy',
        'description': 'Promoting AI and technology adoption in agriculture for better yields',
        'benefits': 'Access to AI tools, Smart farming advisory',
        'eligibility_criteria': 'Farmers in Maharashtra',
        'documents_required': 'Land documents, Aadhaar card, Bank account',
        'application_link': 'https://krishi.maharashtra.gov.in/',
        'state_applicability': 'Maharashtra',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Technology'
    },
    {
        'scheme_id': 'NPGI_001',
        'scheme_name': 'NERAMAC & Precision Grow Initiative',
        'description': 'Technology-driven support for high-value crops in North East',
        'benefits': 'Precision farming tools, Market linkage',
        'eligibility_criteria': 'Farmers in North East India',
        'documents_required': 'Land documents, Aadhaar card, Bank account',
        'application_link': 'https://neramac.com/',
        'state_applicability': 'North East India',
        'crop_types': 'Horticulture,Spices',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Technology'
    },
    {
        'scheme_id': 'APART_001',
        'scheme_name': 'APART (Assam Agribusiness and Rural Transformation)',
        'description': 'Improving resilience of agriculture production systems and value addition',
        'benefits': 'Market access, Value chain development',
        'eligibility_criteria': 'Farmers and agri-entrepreneurs in Assam',
        'documents_required': 'Land documents, Aadhaar card, Bank account',
        'application_link': 'https://apart.assam.gov.in/',
        'state_applicability': 'Assam',
        'crop_types': 'Rice,Fisheries,Horticulture',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Advisory'
    },
    {
        'scheme_id': 'KYSY_001',
        'scheme_name': 'Krishi Yantra Subsidy Yojana',
        'description': 'Subsidy on agricultural machinery to promote mechanization',
        'benefits': 'Subsidy up to 50% on farm equipment',
        'eligibility_criteria': 'Farmers in Uttar Pradesh',
        'documents_required': 'Land documents, Aadhaar card, Bank account',
        'application_link': 'https://upagriculture.com/',
        'state_applicability': 'Uttar Pradesh',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Technology'
    },
    {
        'scheme_id': 'MKKY_001',
        'scheme_name': 'Mukhyamantri Kisan Kalyan Yojana',
        'description': 'State top-up to PM-KISAN scheme for additional income support',
        'benefits': 'Additional ₹4000/year to PM-KISAN beneficiaries',
        'eligibility_criteria': 'PM-KISAN beneficiaries in MP',
        'documents_required': 'Aadhaar card, PM-KISAN registration',
        'application_link': 'https://saara.mp.gov.in/',
        'state_applicability': 'Madhya Pradesh',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal',
        'scheme_type': 'Financial Support'
    },
    {
        'scheme_id': 'TY_001',
        'scheme_name': 'Tarbandi Yojana',
        'description': 'Subsidy for fencing fields to protect crops from stray animals',
        'benefits': 'Subsidy for wire fencing',
        'eligibility_criteria': 'Farmers in Rajasthan',
        'documents_required': 'Land documents, Aadhaar card, Bank account',
        'application_link': 'https://agriculture.rajasthan.gov.in/',
        'state_applicability': 'Rajasthan',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Infrastructure'
    },
    {
        'scheme_id': 'MKSY_001',
        'scheme_name': 'Mukhyamantri Kisan Sahay Yojana',
        'description': 'Compensation to farmers for crop loss due to natural calamities (replacing insurance)',
        'benefits': 'Compensation for crop loss without premium',
        'eligibility_criteria': 'Farmers in Gujarat',
        'documents_required': 'Land documents, Aadhaar card, Crop loss report',
        'application_link': 'https://agri.gujarat.gov.in/',
        'state_applicability': 'Gujarat',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Insurance'
    },
    {
        'scheme_id': 'RSS_001',
        'scheme_name': 'Raitha Siri Scheme',
        'description': 'Incentive for millet cultivation to promote sustainable agriculture',
        'benefits': 'Financial incentive of ₹10000/hectare for millet growers',
        'eligibility_criteria': 'Millet farmers in Karnataka',
        'documents_required': 'Land documents, Aadhaar card, Bank account',
        'application_link': 'https://raitamitra.karnataka.gov.in/',
        'state_applicability': 'Karnataka',
        'crop_types': 'Millets',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Financial Support'
    },
    {
        'scheme_id': 'BSB_001',
        'scheme_name': 'Bangla Shasya Bima',
        'description': 'Crop insurance scheme with full premium paid by state government',
        'benefits': 'Free crop insurance coverage',
        'eligibility_criteria': 'Farmers in West Bengal',
        'documents_required': 'Land documents, Aadhaar card, Voter ID',
        'application_link': 'https://banglashasyabima.net/',
        'state_applicability': 'West Bengal',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Insurance'
    },
    {
        'scheme_id': 'BRFSY_001',
        'scheme_name': 'Bihar Rajya Fasal Sahayata Yojana',
        'description': 'Financial assistance for crop damage due to natural calamities',
        'benefits': 'Compensation based on yield loss',
        'eligibility_criteria': 'Farmers in Bihar',
        'documents_required': 'Land documents, Aadhaar card, Self-declaration',
        'application_link': 'https://pacsonline.bih.nic.in/',
        'state_applicability': 'Bihar',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Insurance'
    },
    {
        'scheme_id': 'SK_001',
        'scheme_name': 'Subhiksha Keralam',
        'description': 'Comprehensive program to achieve food security and sustainable farming',
        'benefits': 'Subsidy for intercropping, fallow land cultivation',
        'eligibility_criteria': 'Farmers in Kerala',
        'documents_required': 'Land documents, Aadhaar card, Bank account',
        'application_link': 'https://keralaagriculture.gov.in/',
        'state_applicability': 'Kerala',
        'crop_types': 'Vegetables,Fruits,Tubers',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Subsidy'
    },
    {
        'scheme_id': 'YRB_001',
        'scheme_name': 'YSR Rythu Bharosa',
        'description': 'Financial assistance to farmers for crop investment',
        'benefits': 'Annual financial assistance of ₹13500',
        'eligibility_criteria': 'Farmers in Andhra Pradesh',
        'documents_required': 'Land documents, Aadhaar card, Bank account',
        'application_link': 'https://ysrrythubharosa.ap.gov.in/',
        'state_applicability': 'Andhra Pradesh',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Tenant',
        'scheme_type': 'Financial Support'
    },
    {
        'scheme_id': 'MMKSY_001',
        'scheme_name': 'Mukhya Mantri Khet Sanrakshan Yojana',
        'description': 'Solar fencing subsidy to protect crops from wild animals',
        'benefits': 'Subsidy for solar fencing',
        'eligibility_criteria': 'Farmers in Himachal Pradesh',
        'documents_required': 'Land documents, Aadhaar card, Bank account',
        'application_link': 'https://agri.hp.gov.in/',
        'state_applicability': 'Himachal Pradesh',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Infrastructure'
    },
    {
        'scheme_id': 'GKY_001',
        'scheme_name': 'Ghasyari Kalyan Yojana',
        'description': 'Providing nutritious fodder and reducing drudgery for rural women',
        'benefits': 'Distribution of silage/fodder kits',
        'eligibility_criteria': 'Rural women and livestock owners in Uttarakhand',
        'documents_required': 'Aadhaar card, Ration card',
        'application_link': 'https://uk.gov.in/',
        'state_applicability': 'Uttarakhand',
        'crop_types': 'Fodder Crops',
        'farmer_category': 'Small,Marginal',
        'scheme_type': 'Livestock'
    }
]

# Create DataFrame
schemes_df = pd.DataFrame(schemes_data)

# Define absolute path to save location
save_dir = r'C:\Users\KIIT\Desktop\AgriShield\data\processed'
os.makedirs(save_dir, exist_ok=True)

# Define filename and full path
csv_filename = 'government_schemes.csv'
csv_filepath = os.path.join(save_dir, csv_filename)

# Save to CSV
schemes_df.to_csv(csv_filepath, index=False, encoding='utf-8')

# Display summary
print(f'✅ Successfully saved {len(schemes_df)} schemes')
print(f'\n📊 Dataset Summary:')
print(f'   - Total schemes: {len(schemes_df)}')
print(f'   - Columns: {len(schemes_df.columns)}')
print(f'   - States covered: {schemes_df["state_applicability"].nunique()}')
print(f'   - Scheme types: {schemes_df["scheme_type"].nunique()}')
print(f'   - Saved to: {csv_filepath}')
# Out:
# ✅ Successfully saved 34 schemes
#
# 📊 Dataset Summary:
#    - Total schemes: 34
#    - Columns: 11
#    - States covered: 20
#    - Scheme types: 9
#    - Saved to: C:\Users\KIIT\Desktop\AgriShield\data\processed\government_schemes.csv
