# %% [markdown]
# # Government Schemes Recommendation System 2026 - Expanded Edition
#
# This notebook processes **67 government agricultural schemes** from across India (2026) and provides:
# - Personalized scheme recommendations
# - Comprehensive crop descriptions
# - Detailed growing tips for each crop type
# - Coverage of all states and union territories
#
# **New Features:**
# - 34 additional state-specific schemes
# - Union Territory schemes included
# - Technology schemes (AI, drones, solar)
# - Sustainability initiatives
# - Specialty crops coverage

# %% [markdown]
# ## 1. Import Libraries and Load Data

# %%
import pandas as pd
import os
print('✅ Ready to load schemes!')
# Out:
# ✅ Ready to load schemes!

# %%
schemes_data = [
    {
        'scheme_id': 'PM_KISAN_001',
        'scheme_name': 'PM-KISAN (Pradhan Mantri Kisan Samman Nidhi)',
        'description': 'Income support of ₹6000 per year in three equal installments to all landholding farmer families',
        'benefits': 'The scheme provides comprehensive support including ₹6000/year in 3 installments of ₹2000 each. Furthermore, it offers direct benefit transfer to bank account.',
        'eligibility_criteria': 'This scheme is primarily targeted at landholding farmer families. The scheme also covers all states except assam. It is applicable to meghalaya. Furthermore, eligibility extends to j&k. Additionally, it includes ladakh initially.',
        'documents_required': 'Aadhaar card, Bank account details, Land ownership documents, Self-declaration form',
        'application_link': 'https://pmkisan.gov.in/RegistrationFormupdated.aspx',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Financial Support',
        'required_documents': 'Aadhaar, Bank passbook, Land records',
    },
    {
        'scheme_id': 'PMFBY_001',
        'scheme_name': 'PMFBY (Pradhan Mantri Fasal Bima Yojana)',
        'description': 'Crop insurance scheme providing financial support to farmers in case of crop loss',
        'benefits': 'Key benefits of this initiative include coverage against crop loss due to natural calamities. Furthermore, it offers pests & diseases. Low premium rates: 2% for kharif. Additionally, the scheme provides 1. 5% for rabi. Moreover, beneficiaries receive 5% for horticulture.',
        'eligibility_criteria': 'The scheme is designed to benefit all farmers including sharecroppers and tenant farmers. The scheme also covers applicable for notified crops.',
        'documents_required': 'Aadhaar card, Bank account details, Land records, Sowing certificate',
        'application_link': 'https://pmfby.gov.in',
        'state_applicability': 'All States',
        'crop_types': 'Rice,Wheat,Cotton,Sugarcane,Pulses,Oilseeds',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Insurance',
        'required_documents': 'Aadhaar, Bank account, Land records',
    },
    {
        'scheme_id': 'SHC_001',
        'scheme_name': 'Soil Health Card Scheme',
        'description': 'Provides soil health cards to farmers every 2 years with soil nutrient status and fertilizer recommendations',
        'benefits': 'The scheme provides comprehensive support including free soil testing. Furthermore, it offers customized fertilizer recommendations. Additionally, the scheme provides improved soil health management. Moreover, beneficiaries receive reduced input costs.',
        'eligibility_criteria': 'Eligibility for this program is extended to all farmers with agricultural land.',
        'documents_required': 'Land ownership documents, Aadhaar card, Soil samples',
        'application_link': 'https://soilhealth.dac.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Advisory',
        'required_documents': 'Aadhaar, Land documents',
    },
    {
        'scheme_id': 'KCC_001',
        'scheme_name': 'Kisan Credit Card (KCC)',
        'description': 'Credit facility for farmers to meet crop production and related expenses',
        'benefits': 'This program offers significant advantages such as credit up to ₹3 lakhs at 7% interest. Furthermore, it offers additional 3% interest subvention on timely repayment. Additionally, the scheme provides flexible repayment terms.',
        'eligibility_criteria': 'Eligibility for this program is extended to individual/joint borrowers who are owner cultivators. The scheme also covers tenant farmers. It is applicable to sharecroppers. Furthermore, eligibility extends to oral lessees.',
        'documents_required': 'Identity proof, Address proof, Land documents, Passport size photographs',
        'application_link': 'https://pmkisan.gov.in',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Credit',
        'required_documents': 'ID proof, Address proof, Land docs, Photos',
    },
    {
        'scheme_id': 'PM_KMY_001',
        'scheme_name': 'PM Kisan Maan-Dhan Yojana (Pension Scheme)',
        'description': 'Old age pension scheme for small and marginal farmers',
        'benefits': 'The scheme provides comprehensive support including ₹3000 monthly pension after age 60. Furthermore, it offers family pension of 50% to spouse. Additionally, the scheme provides life and disability insurance coverage.',
        'eligibility_criteria': 'Applicants must fall under the category of small and marginal farmers aged 18-40 years. The scheme also covers landholding up to 2 hectares. It is applicable to not covered under other pension schemes.',
        'documents_required': 'Aadhaar card, Bank account passbook, Age proof, Land records',
        'application_link': 'https://maandhan.in',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal',
        'scheme_type': 'Pension',
        'required_documents': 'Aadhaar, Bank passbook, Age proof',
    },
    {
        'scheme_id': 'PKVY_001',
        'scheme_name': 'National Mission For Sustainable Agriculture-Parmparagat Krishi Vikas Yojana (NMSA-PKVY)',
        'description': 'Promotes cluster-based organic farming under NMSA for sustainable agriculture.',
        'benefits': 'This program offers significant advantages such as ₹50. Furthermore, it offers 000/ha for 3 years for cluster formation. Additionally, the scheme provides organic inputs. Moreover, beneficiaries receive certification support. It also aims to ensure infrastructure support for packing/marketing.',
        'eligibility_criteria': 'Applicants must fall under the category of farmers willing to adopt organic farming. The scheme also covers group/cluster based approach.',
        'documents_required': 'Group formation documents, Land details, Aadhaar card, Bank account, Detailed Project Report',
        'application_link': 'https://www.myscheme.gov.in/schemes/nmsa-pkvy',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal',
        'scheme_type': 'Organic',
        'required_documents': 'Group docs, Land details, DPR',
    },
    {
        'scheme_id': 'PMKSY_001',
        'scheme_name': 'PMKSY (Pradhan Mantri Krishi Sinchayee Yojana)',
        'description': 'Aims to expand cultivated area with assured irrigation, improve water use efficiency',
        'benefits': 'The scheme provides comprehensive support including subsidy for drip/sprinkler irrigation. Furthermore, it offers micro-irrigation support. Additionally, the scheme provides watershed development.',
        'eligibility_criteria': 'This scheme is primarily targeted at individual farmers. The scheme also covers self-help groups. It is applicable to community organizations.',
        'documents_required': 'Land documents, Aadhaar card, Bank account details, Project proposal',
        'application_link': 'https://pmksy.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'Rice,Wheat,Cotton,Sugarcane,Vegetables,Fruits',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Subsidy',
        'required_documents': 'Land docs, Aadhaar, Bank account',
    },
    {
        'scheme_id': 'NDDS_001',
        'scheme_name': 'Namo Drone Didi Scheme',
        'description': 'Empowering Women Self Help Groups (SHGs) with drones for agricultural rental services',
        'benefits': 'Under this scheme, beneficiaries are entitled to 80% subsidy (up to ₹8 lakh) for drones. Furthermore, it offers free drone pilot training. Additionally, the scheme provides income generation.',
        'eligibility_criteria': 'The scheme is designed to benefit women self help groups (shgs).',
        'documents_required': 'SHG registration documents, Aadhaar cards of members, Bank account details',
        'application_link': 'https://agriharyana.gov.in/AgriShaktiNamoDroneDidi.aspx',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Technology',
        'required_documents': 'SHG registration, Aadhaar, Bank details',
    },
    {
        'scheme_id': 'KSP_001',
        'scheme_name': 'Krishi Sakhi Program',
        'description': 'Training rural women as Para-extension Workers to support farmers with modern agricultural practices',
        'benefits': 'This program offers significant advantages such as certification as krishi sakhi. Furthermore, it offers income opportunity as community resource persons. Additionally, the scheme provides skill development.',
        'eligibility_criteria': 'Eligibility for this program is extended to women farmers. The scheme also covers rural women interested in agriculture extension.',
        'documents_required': 'Aadhaar card, Education certificates (if any), Bank account details',
        'application_link': 'https://www.manage.gov.in/KrishiSakhi/login.aspx',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Advisory',
        'required_documents': 'Aadhaar, Education certs',
    },
    {
        'scheme_id': 'MKSP_001',
        'scheme_name': 'Mahila Kisan Sashaktikaran Pariyojana (MKSP)',
        'description': 'Empowering women in agriculture through sustainable practices and capacity building',
        'benefits': 'This program offers significant advantages such as training in sustainable agriculture. Furthermore, it offers support for community institutions. Additionally, the scheme provides improved access to inputs and markets.',
        'eligibility_criteria': 'This scheme is primarily targeted at women farmers. The scheme also covers mahila kisans.',
        'documents_required': 'Aadhaar card, SHG membership proof (if applicable), Land documents (optional)',
        'application_link': 'https://mksp.nrlm.gov.in/portal/',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal',
        'scheme_type': 'Financial Support',
        'required_documents': 'Aadhaar, SHG proof',
    },
    {
        'scheme_id': 'ENAM_001',
        'scheme_name': 'e-NAM (National Agriculture Market)',
        'description': 'Unified national online trading platform for agricultural commodities',
        'benefits': 'This program offers significant advantages such as online trading. Furthermore, it offers better price discovery. Additionally, the scheme provides transparent bidding. Moreover, beneficiaries receive reduced transaction costs. It also aims to ensure pan-india market access.',
        'eligibility_criteria': 'Eligibility for this program is extended to all farmers. The scheme also covers traders. It is applicable to commission agents.',
        'documents_required': 'Aadhaar card linked to bank account',
        'application_link': 'https://enam.gov.in/web/Enam_ctrl/enam_registration',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Market Access',
        'required_documents': 'Aadhaar, Bank account',
    },
    {
        'scheme_id': 'FPO_10K_001',
        'scheme_name': 'Formation and Promotion of 10000 FPOs',
        'description': 'Central Sector Scheme to form and promote 10000 Farmer Producer Organizations',
        'benefits': 'Under this scheme, beneficiaries are entitled to ₹18 lakh per fpo over 3 years. Furthermore, it offers matching equity grant up to ₹15 lakh. Additionally, the scheme provides credit guarantee up to ₹2 crore. Moreover, beneficiaries receive professional handholding for 5 years.',
        'eligibility_criteria': 'Eligibility for this program is extended to farmer groups. The scheme also covers minimum 300 members in plains. It is applicable to 100 in hilly/tribal areas.',
        'documents_required': 'FPO registration, Member list, Bank account, Business plan',
        'application_link': 'https://sfacindia.com',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal',
        'scheme_type': 'Institutional Support',
        'required_documents': 'FPO registration, Member list, Business plan',
    },
    {
        'scheme_id': 'SMAM_001',
        'scheme_name': 'Sub-Mission on Agricultural Mechanization (SMAM)',
        'description': 'Increasing the reach of farm mechanization to small and marginal farmers',
        'benefits': 'This program offers significant advantages such as 50-80% subsidy on agricultural machinery. Furthermore, it offers support for custom hiring centres. Additionally, the scheme provides high-tech equipment hubs.',
        'eligibility_criteria': 'The scheme is designed to benefit all farmers. The scheme also covers fpos. It is applicable to shgs. Furthermore, eligibility extends to sc/st and women farmers get special benefits.',
        'documents_required': 'Aadhaar Card, Land Records, Bank Passbook, Caste Certificate (if applicable)',
        'application_link': 'https://agrimachinery.nic.in',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Technology',
        'required_documents': 'Aadhaar, Land docs, Bank passbook',
    },
    {
        'scheme_id': 'DAM_001',
        'scheme_name': 'Digital Agriculture Mission',
        'description': 'Building Digital Public Infrastructure for agriculture to provide farmers with real-time data and services',
        'benefits': 'The scheme provides comprehensive support including access to digital services. Furthermore, it offers real-time weather and market info. Additionally, the scheme provides digital identities for farmers. Moreover, beneficiaries receive ai-driven recommendations.',
        'eligibility_criteria': 'The scheme is designed to benefit all farmers.',
        'documents_required': 'Aadhaar card, Mobile number linked to Aadhaar',
        'application_link': 'https://mybharat.gov.in/mega_events/digital-agriculture-mission-tech-for-transforming-farmers-lives',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Technology',
        'required_documents': 'Aadhaar, Mobile number',
    },
    {
        'scheme_id': 'PMDDKY_001',
        'scheme_name': 'Prime Minister Dhan-Dhaanya Krishi Yojana',
        'description': 'Targeting 100 low-productivity districts to boost yield through modern techniques',
        'benefits': 'This program offers significant advantages such as enhanced credit access. Furthermore, it offers improved irrigation facilities. Additionally, the scheme provides modern cultivation technique support. Moreover, beneficiaries receive productivity enhancement.',
        'eligibility_criteria': 'The scheme is designed to benefit farmers in identified 100 districts.',
        'documents_required': 'Land documents, Aadhaar card, Bank account',
        'application_link': 'https://pmkisan-yojana.org/pm-dhan-dhaanya-krishi-yojana/',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal',
        'scheme_type': 'Financial Support',
        'required_documents': 'Land docs, Aadhaar, Bank account',
    },
    {
        'scheme_id': 'NMEO_OP_001',
        'scheme_name': 'National Mission on Edible Oils - Oil Palm (NMEO-OP)',
        'description': 'Promoting oil palm cultivation to reduce import dependency',
        'benefits': 'Key benefits of this initiative include viability price assurance. Furthermore, it offers subsidy for planting material (₹29000/ha). Additionally, the scheme provides intercropping support. Moreover, beneficiaries receive market linkage.',
        'eligibility_criteria': 'Eligibility for this program is extended to farmers in potential states (south and north east).',
        'documents_required': 'Land documents, Aadhaar card, Bank account',
        'application_link': 'https://nmeo.dac.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'Oil Palm',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Subsidy',
        'required_documents': 'Land docs, Aadhaar, Bank account',
    },
    {
        'scheme_id': 'NMEO_OS_001',
        'scheme_name': 'National Mission on Edible Oils - Oilseeds (NMEO-OS)',
        'description': 'Boosting production of 9 key oilseeds to achieve self-sufficiency',
        'benefits': 'This program offers significant advantages such as quality seed distribution. Furthermore, it offers cluster demonstrations. Additionally, the scheme provides high yielding varieties support. Moreover, beneficiaries receive technology transfer.',
        'eligibility_criteria': 'Applicants must fall under the category of farmers cultivating oilseeds.',
        'documents_required': 'Land documents, Aadhaar card',
        'application_link': 'https://nmeo.dac.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'Groundnut,Soyabean,Rapeseed,Mustard,Sunflower,Sesamum,Safflower,Niger Seed,Linseed,Castor',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Production',
        'required_documents': 'Land docs, Aadhaar',
    },
    {
        'scheme_id': 'PM_AASHA_001',
        'scheme_name': 'PM-AASHA (Pradhan Mantri Annadata Aay SanraksHan Abhiyan)',
        'description': 'Price support scheme for Oilseeds and Copra',
        'benefits': 'This program offers significant advantages such as procurement at msp. Furthermore, it offers price deficiency payment if market price falls below msp. Additionally, the scheme provides market intervention scheme.',
        'eligibility_criteria': 'Eligibility for this program is extended to oilseeds and copra farmers.',
        'documents_required': 'Land documents, Aadhaar card, Bank account, Sale receipt',
        'application_link': 'https://pmaymis.gov.in/pmaymis2_2024/PMAY_SURVEY/Applicant_Login.aspx',
        'state_applicability': 'All States',
        'crop_types': 'Groundnut,Soyabean,Rapeseed,Mustard,Sunflower,Sesamum,Niger Seed,Copra',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Financial Support',
        'required_documents': 'Land docs, Aadhaar, Bank account',
    },
    {
        'scheme_id': 'NFSM_001',
        'scheme_name': 'National Food Security Mission (NFSM)',
        'description': 'Increasing production and productivity of rice wheat pulses and coarse cereals',
        'benefits': 'The scheme provides comprehensive support including quality seeds distribution. Furthermore, it offers cluster demonstrations. Additionally, the scheme provides integrated pest management. Moreover, beneficiaries receive soil health management. It also aims to ensure farm mechanization support.',
        'eligibility_criteria': 'This scheme is primarily targeted at all farmers growing target crops.',
        'documents_required': 'Aadhaar card, Bank account, Land records',
        'application_link': 'https://nfsm.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'Rice,Wheat,Pulses,Millets,Coarse Cereals',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Production',
        'required_documents': 'Aadhaar, Bank account, Land docs',
    },
    {
        'scheme_id': 'MIDH_001',
        'scheme_name': 'Mission for Integrated Development of Horticulture (MIDH)',
        'description': 'Holistic growth of horticulture sector covering fruits vegetables flowers spices',
        'benefits': 'Key benefits of this initiative include area expansion subsidy. Furthermore, it offers protected cultivation support. Additionally, the scheme provides post-harvest management. Moreover, beneficiaries receive marketing infrastructure. It also aims to ensure planting material subsidy.',
        'eligibility_criteria': 'Applicants must fall under the category of all horticulture farmers.',
        'documents_required': 'Aadhaar card, Bank account, Land records, Project proposal',
        'application_link': 'https://midh.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'Fruits,Vegetables,Flowers,Spices,Coconut,Cashew,Cocoa',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Production',
        'required_documents': 'Aadhaar, Bank account, Land docs',
    },
    {
        'scheme_id': 'AIF_001',
        'scheme_name': 'Agriculture Infrastructure Fund',
        'description': 'Medium to long-term debt financing for investment in viable projects for post-harvest management infrastructure',
        'benefits': 'The scheme provides comprehensive support including ₹1 lakh crore fund. Furthermore, it offers 3% interest subvention. Additionally, the scheme provides 9% interest cap. Moreover, beneficiaries receive credit guarantee. It also aims to ensure loans up to ₹2 crore.',
        'eligibility_criteria': 'This scheme is primarily targeted at farmers. The scheme also covers fpos. It is applicable to cooperatives. Furthermore, eligibility extends to entrepreneurs. Additionally, it includes processing units.',
        'documents_required': 'Project report, Land documents, Bank statements, KYC documents',
        'application_link': 'https://agriinfra.dac.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Infrastructure',
        'required_documents': 'Project report, Land docs, Bank statements',
    },
    {
        'scheme_id': 'PMMSY_001',
        'scheme_name': 'PM Matsya Sampada Yojana',
        'description': 'Holistic development of fisheries sector',
        'benefits': 'This program offers significant advantages such as infrastructure development. Furthermore, it offers fish production increase. Additionally, the scheme provides market access. Moreover, beneficiaries receive quality seed. It also aims to ensure employment generation.',
        'eligibility_criteria': 'Applicants must fall under the category of fish farmers. The scheme also covers fisherfolk. It is applicable to fish workers. Furthermore, eligibility extends to self-help groups. Additionally, it includes fpos.',
        'documents_required': 'Aadhaar card, Bank account, Project proposal, Land/water body lease',
        'application_link': 'https://pmmsy.dof.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'Fisheries',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Production',
        'required_documents': 'Aadhaar, Bank account, Project proposal',
    },
    {
        'scheme_id': 'NBHM_001',
        'scheme_name': 'National Beekeeping and Honey Mission (NBHM)',
        'description': 'Promoting scientific beekeeping for honey production',
        'benefits': 'Under this scheme, beneficiaries are entitled to subsidy for beehives. Furthermore, it offers training support. Additionally, the scheme provides market linkage. Moreover, beneficiaries receive honey processing units. It also aims to ensure quality testing labs.',
        'eligibility_criteria': 'Applicants must fall under the category of all farmers. The scheme also covers youth. It is applicable to women shgs.',
        'documents_required': 'Aadhaar card, Bank account, Training certificate',
        'application_link': 'https://madhukranti.in/NBB/frm_registration_new.aspx',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Allied Sector',
        'required_documents': 'Aadhaar, Bank account',
    },
    {
        'scheme_id': 'NMMI_001',
        'scheme_name': 'National Mission on Micro Irrigation (Per Drop More Crop)',
        'description': 'Promotion of micro irrigation to enhance water use efficiency',
        'benefits': 'Under this scheme, beneficiaries are entitled to 50-55% subsidy for drip/sprinkler systems. Furthermore, it offers higher subsidy for small farmers. Additionally, the scheme provides on-farm water management.',
        'eligibility_criteria': 'This scheme is primarily targeted at all farmers with assured water source.',
        'documents_required': 'Aadhaar card, Bank account, Land records, Water source proof',
        'application_link': 'https://pdmc.da.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Subsidy',
        'required_documents': 'Aadhaar, Bank account, Land docs',
    },
    {
        'scheme_id': 'RKVY_001',
        'scheme_name': 'Rashtriya Krishi Vikas Yojana (RKVY-RAFTAAR)',
        'description': 'State-specific agriculture development projects and infrastructure creation',
        'benefits': 'Under this scheme, beneficiaries are entitled to flexible funding for state projects. Furthermore, it offers innovation fund. Additionally, the scheme provides agri-entrepreneurship development. Moreover, beneficiaries receive infrastructure creation.',
        'eligibility_criteria': 'The scheme is designed to benefit state governments. The scheme also covers farmers. It is applicable to entrepreneurs. Furthermore, eligibility extends to fpos.',
        'documents_required': 'As per state guidelines and project requirements',
        'application_link': 'https://rkvy.da.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Infrastructure',
        'required_documents': 'As per state norms',
    },
    {
        'scheme_id': 'NMSA_001',
        'scheme_name': 'National Mission for Sustainable Agriculture (NMSA)',
        'description': 'Promoting sustainable agriculture practices',
        'benefits': 'The scheme provides comprehensive support including soil health management. Furthermore, it offers water conservation. Additionally, the scheme provides resource efficiency. Moreover, beneficiaries receive climate resilient agriculture.',
        'eligibility_criteria': 'Eligibility for this program is extended to all farmers.',
        'documents_required': 'Aadhaar card, Bank account, Land records',
        'application_link': 'https://nmsa.dac.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Sustainability',
        'required_documents': 'Aadhaar, Bank account, Land docs',
    },
    {
        'scheme_id': 'KISAN_CALL_001',
        'scheme_name': 'Kisan Call Center (KCC)',
        'description': 'Toll-free helpline for agriculture-related queries',
        'benefits': 'This program offers significant advantages such as 24x7 toll-free service. Furthermore, it offers expert advice in local languages. Additionally, the scheme provides immediate solutions to farm problems.',
        'eligibility_criteria': 'Applicants must fall under the category of all farmers.',
        'documents_required': 'Mobile phone for calling',
        'application_link': 'https://dackkms.gov.in/account/login.aspx',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Advisory',
        'required_documents': 'Mobile phone',
    },
    {
        'scheme_id': 'MKISAN_001',
        'scheme_name': 'mKisan Portal and SMS Advisory',
        'description': 'Mobile-based agri-advisory services',
        'benefits': 'Under this scheme, beneficiaries are entitled to free sms advisory. Furthermore, it offers weather alerts. Additionally, the scheme provides market prices. Moreover, beneficiaries receive scheme information. It also aims to ensure expert tips.',
        'eligibility_criteria': 'This scheme is primarily targeted at all farmers.',
        'documents_required': 'Mobile number registration',
        'application_link': 'https://mkisan.gov.in/Home/RegisterForKsewa',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Advisory',
        'required_documents': 'Mobile number',
    },
    {
        'scheme_id': 'ACABC_001',
        'scheme_name': 'Agri-Clinics and Agri-Business Centres',
        'description': 'Support for agricultural graduates to set up agri-clinics and agri-business centres',
        'benefits': 'Under this scheme, beneficiaries are entitled to 36-44% subsidy on project cost. Furthermore, it offers bank loan assistance. Additionally, the scheme provides free training. Moreover, beneficiaries receive business development support.',
        'eligibility_criteria': 'This scheme is primarily targeted at agriculture graduates/diploma holders.',
        'documents_required': 'Educational certificates, Project report, Aadhaar, Bank account',
        'application_link': 'https://www.agriclinics.net',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Advisory',
        'required_documents': 'Degree certificates, Project report',
    },
    {
        'scheme_id': 'AMI_001',
        'scheme_name': 'Agricultural Marketing Infrastructure (AMI)',
        'description': 'Development of agricultural marketing infrastructure including storage and grading facilities',
        'benefits': 'Under this scheme, beneficiaries are entitled to 25-33. 33% subsidy on capital cost. Furthermore, it offers credit-linked back-ended subsidy. Additionally, the scheme provides infrastructure development support.',
        'eligibility_criteria': 'Applicants must fall under the category of farmers. The scheme also covers fpos. It is applicable to cooperatives. Furthermore, eligibility extends to individuals. Additionally, it includes partnership firms, and ngos.',
        'documents_required': 'Land documents, Detailed Project Report, Bank Loan Sanction Letter, KYC documents',
        'application_link': 'https://dmi.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Infrastructure',
        'required_documents': 'Project Report, Land docs, Bank sanction',
    },
    {
        'scheme_id': 'RAD_001',
        'scheme_name': 'Rainfed Area Development (RAD)',
        'description': 'Promoting sustainable Integrated Farming Systems in rainfed areas',
        'benefits': 'Under this scheme, beneficiaries are entitled to financial assistance ₹30000-50000 per hectare. Furthermore, it offers integrated farming support. Additionally, the scheme provides climate risk minimization.',
        'eligibility_criteria': 'Applicants must fall under the category of farmers in rainfed clusters/districts.',
        'documents_required': 'Land documents, Aadhaar Card, Bank Account Details',
        'application_link': 'https://nmsa.dac.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Sustainability',
        'required_documents': 'Land docs, Aadhaar',
    },
    {
        'scheme_id': 'NMNF_001',
        'scheme_name': 'National Mission on Natural Farming',
        'description': 'Promoting chemical-free natural farming practices',
        'benefits': 'Key benefits of this initiative include ₹2481 crore allocation. Furthermore, it offers training support. Additionally, the scheme provides financial assistance. Moreover, beneficiaries receive organic certification. It also aims to ensure market linkage.',
        'eligibility_criteria': 'Eligibility for this program is extended to all farmers willing to adopt natural farming.',
        'documents_required': 'Aadhaar card, Bank account, Land records',
        'application_link': 'https://naturalfarming.dac.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Organic',
        'required_documents': 'Aadhaar, Bank account, Land docs',
    },
    {
        'scheme_id': 'DALHAN_001',
        'scheme_name': 'Dalhan Atmanirbharta Mission (Pulse Self-Reliance)',
        'description': 'Focus on Tur Urad and Masoor pulses for self-sufficiency',
        'benefits': 'Under this scheme, beneficiaries are entitled to ₹11440 crore budget. Furthermore, it offers quality seed distribution. Additionally, the scheme provides technology support. Moreover, beneficiaries receive market procurement. It also aims to ensure msp support.',
        'eligibility_criteria': 'Eligibility for this program is extended to pulse growing farmers.',
        'documents_required': 'Aadhaar card, Bank account, Land records',
        'application_link': 'https://kisanportal.org/dalhan-aatmanirbharta-mission/',
        'state_applicability': 'All States',
        'crop_types': 'Tur,Urad,Masoor,Pulses',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Production',
        'required_documents': 'Aadhaar, Bank account, Land docs',
    },
    {
        'scheme_id': 'RB_001',
        'scheme_name': 'Rythu Bharosa (Telangana)',
        'description': 'Investment support for agriculture and horticulture crops',
        'benefits': 'This program offers significant advantages such as ₹10000 per acre per year. Furthermore, it offers direct cash transfer. Additionally, the scheme provides two installments per year.',
        'eligibility_criteria': 'Eligibility for this program is extended to land owning farmers in telangana.',
        'documents_required': 'Land documents, Aadhaar card, Bank account, Pattadar passbook',
        'application_link': 'https://rythubharosa.telangana.gov.in',
        'state_applicability': 'Telangana',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Financial Support',
        'required_documents': 'Land docs, Aadhaar, Bank account',
    },
    {
        'scheme_id': 'RYTHU_BHEEMA_001',
        'scheme_name': 'Rythu Bheema Scheme (Telangana)',
        'description': 'Life insurance for farmers',
        'benefits': 'This program offers significant advantages such as ₹5 lakh coverage. Furthermore, it offers accidental death and disability coverage. Additionally, the scheme provides zero premium.',
        'eligibility_criteria': 'Eligibility for this program is extended to farmers in telangana aged 18-59 years.',
        'documents_required': 'Aadhaar card, Bank account, Pattadar passbook',
        'application_link': 'https://www.myscheme.gov.in/schemes/rythu-bima',
        'state_applicability': 'Telangana',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Insurance',
        'required_documents': 'Aadhaar, Bank account',
    },
    {
        'scheme_id': 'VLR_001',
        'scheme_name': 'Vaddi Leni Runalu (Telangana)',
        'description': 'Interest-free loans for farmers',
        'benefits': 'Key benefits of this initiative include crop loans up to ₹1 lakh made interest-free. Furthermore, it offers government pays interest component.',
        'eligibility_criteria': 'The scheme is designed to benefit all eligible farmers in telangana.',
        'documents_required': 'Aadhaar card, Bank account, Land records',
        'application_link': 'https://tgsccfc.cgg.gov.in/getHomeMenuServices?optionId=19',
        'state_applicability': 'Telangana',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Credit',
        'required_documents': 'Aadhaar, Bank account, Land docs',
    },
    {
        'scheme_id': 'KALIA_001',
        'scheme_name': 'KALIA Yojana (Now CM Kisan - Odisha)',
        'description': 'Comprehensive farmer support scheme',
        'benefits': 'This program offers significant advantages such as ₹25000 over 5 seasons for cultivation. Furthermore, it offers ₹12500 for landless laborers. Additionally, the scheme provides ₹10000 for vulnerable farmers. Moreover, beneficiaries receive life insurance ₹2 lakh. It also aims to ensure accident cover ₹2 lakh.',
        'eligibility_criteria': 'Eligibility for this program is extended to farmers. The scheme also covers landless laborers in odisha.',
        'documents_required': 'Aadhaar card, Bank account, Land records (for landholders)',
        'application_link': 'https://cmkisan.odisha.gov.in',
        'state_applicability': 'Odisha',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Financial Support',
        'required_documents': 'Aadhaar, Bank account, Land docs',
    },
    {
        'scheme_id': 'RAITHA_SIRI_001',
        'scheme_name': 'Raitha Siri Scheme (Karnataka)',
        'description': 'Direct income support for farmers',
        'benefits': 'Under this scheme, beneficiaries are entitled to financial assistance per acre regardless of land size. Furthermore, it offers direct benefit transfer.',
        'eligibility_criteria': 'Eligibility for this program is extended to all farmers in karnataka.',
        'documents_required': 'Land documents, Aadhaar card, Bank account',
        'application_link': 'https://raitamitra.karnataka.gov.in/90/Raita%20Siri/en',
        'state_applicability': 'Karnataka',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Financial Support',
        'required_documents': 'Land docs, Aadhaar, Bank account',
    },
    {
        'scheme_id': 'KRISHI_BHAGYA_001',
        'scheme_name': 'Krishi Bhagya Scheme (Karnataka)',
        'description': 'Micro-irrigation promotion and agricultural development',
        'benefits': 'This program offers significant advantages such as borewell subsidy. Furthermore, it offers irrigation infrastructure support. Additionally, the scheme provides micro-irrigation subsidy.',
        'eligibility_criteria': 'Applicants must fall under the category of farmers in karnataka.',
        'documents_required': 'Land documents, Aadhaar card, Bank account',
        'application_link': 'https://raitamitra.karnataka.gov.in/52/Krishi%20Bhagya%20Scheme/en',
        'state_applicability': 'Karnataka',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Infrastructure',
        'required_documents': 'Land docs, Aadhaar, Bank account',
    },
    {
        'scheme_id': 'MAHADBT_001',
        'scheme_name': 'MahaDBT Portal (Maharashtra)',
        'description': 'Unified portal for all agricultural subsidies and schemes',
        'benefits': 'The scheme provides comprehensive support including single window for all schemes. Furthermore, it offers online application. Additionally, the scheme provides tracking facility. Moreover, beneficiaries receive direct benefit transfer.',
        'eligibility_criteria': 'This scheme is primarily targeted at all farmers in maharashtra.',
        'documents_required': 'Aadhaar card, Bank account, Land records (7/12 extract), Caste certificate (if applicable)',
        'application_link': 'https://mahadbt.maharashtra.gov.in/registrationlogin/registrationlogin',
        'state_applicability': 'Maharashtra',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Technology',
        'required_documents': 'Aadhaar, Bank account, 7/12 extract',
    },
    {
        'scheme_id': 'NJDKSY_001',
        'scheme_name': 'Nanaji Deshmukh Krishi Sanjeevani Yojana (Maharashtra)',
        'description': 'Drought-prone area development',
        'benefits': 'The scheme provides comprehensive support including ₹4000 crore world bank project. Furthermore, it offers soil health improvement. Additionally, the scheme provides climate-resilient agriculture. Moreover, beneficiaries receive watershed development.',
        'eligibility_criteria': 'This scheme is primarily targeted at farmers in drought-prone districts of maharashtra.',
        'documents_required': 'Aadhaar card, Bank account, Land records',
        'application_link': 'https://dbt.mahapocra.gov.in/FarmerLogin/FarmerLogin.aspx?T=I&D=1',
        'state_applicability': 'Maharashtra',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Sustainability',
        'required_documents': 'Aadhaar, Bank account, Land docs',
    },
    {
        'scheme_id': 'MFMB_001',
        'scheme_name': 'Meri Fasal Mera Byora (Haryana)',
        'description': 'Farmer and crop registration portal',
        'benefits': 'Key benefits of this initiative include single platform for procurement. Furthermore, it offers insurance. Additionally, the scheme provides loans. Moreover, beneficiaries receive natural calamity assistance. It also aims to ensure msp payment.',
        'eligibility_criteria': 'The scheme is designed to benefit all farmers in haryana.',
        'documents_required': 'Aadhaar card, Mobile number, Bank account, Land records',
        'application_link': 'https://fasal.haryana.gov.in',
        'state_applicability': 'Haryana',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Technology',
        'required_documents': 'Aadhaar, Mobile, Bank account, Land docs',
    },
    {
        'scheme_id': 'HKYA_001',
        'scheme_name': 'Haryana Krishi Yantra Anudan Yojana',
        'description': 'Agricultural equipment subsidy scheme',
        'benefits': 'The scheme provides comprehensive support including 40-50% subsidy on farm equipment. Furthermore, it offers 50% for sc/st and women. Additionally, the scheme provides custom hiring centers support.',
        'eligibility_criteria': 'This scheme is primarily targeted at all farmers in haryana. The scheme also covers special benefits for sc/st and women.',
        'documents_required': 'Aadhaar card, Bank account, Land records, Caste certificate (if applicable)',
        'application_link': 'https://agriharyana.gov.in/MechSMAMScheme.aspx',
        'state_applicability': 'Haryana',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Technology',
        'required_documents': 'Aadhaar, Bank account, Land docs',
    },
    {
        'scheme_id': 'BBY_HAR_001',
        'scheme_name': 'Bhavantar Bharpayee Yojana (Haryana)',
        'description': 'Price deficiency payment for horticulture crops',
        'benefits': 'This program offers significant advantages such as compensation for price difference between protected price and sale price. Furthermore, it offers direct payment to farmers.',
        'eligibility_criteria': 'This scheme is primarily targeted at horticulture farmers in haryana.',
        'documents_required': 'J-Form (Sale receipt), Meri Fasal Mera Byora registration',
        'application_link': 'https://fasal.haryana.gov.in',
        'state_applicability': 'Haryana',
        'crop_types': 'Potato,Onion,Tomato,Cauliflower',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Financial Support',
        'required_documents': 'Sale receipt, MFMB registration',
    },
    {
        'scheme_id': 'UP_KKR_001',
        'scheme_name': 'UP Kisan Karj Rahat Yojana',
        'description': 'Farm loan waiver for small and marginal farmers',
        'benefits': 'This program offers significant advantages such as debt up to ₹1 lakh waived. Furthermore, it offers relief to small and marginal farmers.',
        'eligibility_criteria': 'Applicants must fall under the category of small and marginal farmers in uttar pradesh.',
        'documents_required': 'Aadhaar card, Bank account, Land records, Loan documents',
        'application_link': 'https://pmkisan-yojana.org/kisan-karj-mochan-yojana/',
        'state_applicability': 'Uttar Pradesh',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal',
        'scheme_type': 'Credit',
        'required_documents': 'Aadhaar, Bank account, Loan docs',
    },
    {
        'scheme_id': 'UP_MFS_001',
        'scheme_name': 'Million Farmers School Program (UP)',
        'description': 'Village-level training centers for farmers',
        'benefits': 'Key benefits of this initiative include 17000 kisan pathshalas. Furthermore, it offers practical agricultural education. Additionally, the scheme provides technology transfer. Moreover, beneficiaries receive free training.',
        'eligibility_criteria': 'This scheme is primarily targeted at all farmers in uttar pradesh.',
        'documents_required': 'Aadhaar card',
        'application_link': 'http://upagriculture.com/',
        'state_applicability': 'Uttar Pradesh',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Advisory',
        'required_documents': 'Aadhaar',
    },
    {
        'scheme_id': 'UP_SMAAM_001',
        'scheme_name': 'Smaam Kisan Yojana (UP Mechanization)',
        'description': 'State mechanization scheme with subsidies',
        'benefits': 'This program offers significant advantages such as 50-80% subsidy on modern farm equipment. Furthermore, it offers category-wise differentiation.',
        'eligibility_criteria': 'This scheme is primarily targeted at all farmers in uttar pradesh.',
        'documents_required': 'Aadhaar card, Bank account, Land records',
        'application_link': 'https://agrimachinery.nic.in/',
        'state_applicability': 'Uttar Pradesh',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Technology',
        'required_documents': 'Aadhaar, Bank account, Land docs',
    },
    {
        'scheme_id': 'BIHAR_DBT_001',
        'scheme_name': 'Bihar DBT Agriculture Portal',
        'description': 'Direct Benefit Transfer for all agricultural subsidies',
        'benefits': 'This program offers significant advantages such as unified portal for subsidies. Furthermore, it offers equipment subsidy. Additionally, the scheme provides seed subsidy. Moreover, beneficiaries receive diesel subsidy. It also aims to ensure online application.',
        'eligibility_criteria': 'The scheme is designed to benefit all farmers in bihar.',
        'documents_required': 'Aadhaar card, Bank account, Land records',
        'application_link': 'https://dbtagriculture.bihar.gov.in',
        'state_applicability': 'Bihar',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Technology',
        'required_documents': 'Aadhaar, Bank account, Land docs',
    },
    {
        'scheme_id': 'WB_KB_001',
        'scheme_name': 'Krishak Bandhu Scheme (West Bengal)',
        'description': 'Farmer welfare scheme',
        'benefits': 'This program offers significant advantages such as ₹2 lakh death benefit. Furthermore, it offers income support during cultivation seasons. Additionally, the scheme provides two installments per year.',
        'eligibility_criteria': 'Applicants must fall under the category of all farmers in west bengal.',
        'documents_required': 'Aadhaar card, Bank account, Land records',
        'application_link': 'https://krishakbandhu.wb.gov.in/',
        'state_applicability': 'West Bengal',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Financial Support',
        'required_documents': 'Aadhaar, Bank account, Land docs',
    },
    {
        'scheme_id': 'IKHEDUT_001',
        'scheme_name': 'iKhedut Portal (Gujarat)',
        'description': 'Single-window portal for all agriculture schemes',
        'benefits': 'Key benefits of this initiative include online applications. Furthermore, it offers scheme information. Additionally, the scheme provides subsidy tracking. Moreover, beneficiaries receive farmer registration.',
        'eligibility_criteria': 'Applicants must fall under the category of all farmers in gujarat.',
        'documents_required': 'Aadhaar card, Bank account, Land records (7/12 extract)',
        'application_link': 'https://ikhedut.gujarat.gov.in',
        'state_applicability': 'Gujarat',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Technology',
        'required_documents': 'Aadhaar, Bank account, 7/12 extract',
    },
    {
        'scheme_id': 'GUJ_FAIS_001',
        'scheme_name': 'Farmers Accidental Insurance Scheme - Gujarat',
        'description': 'Comprehensive accident insurance for farmers and family',
        'benefits': 'Under this scheme, beneficiaries are entitled to enhanced compensation for accidents. Furthermore, it offers coverage for farmer spouse and children. Additionally, the scheme provides revised benefits from 2018.',
        'eligibility_criteria': 'Eligibility for this program is extended to farmers in gujarat.',
        'documents_required': 'Aadhaar card, Farmer registration',
        'application_link': 'https://www.govtschemes.in/sites/default/files/2023-03/Gujarat%20Farmer%20Accidental%20Insurance%20Scheme%20Application%20Form.pdf?v=1',
        'state_applicability': 'Gujarat',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Insurance',
        'required_documents': 'Aadhaar',
    },
    {
        'scheme_id': 'GUJ_PRAKRUTIK_001',
        'scheme_name': 'Gujarat Prakrutik Krishi Yojana',
        'description': 'Promotion of natural farming',
        'benefits': 'The scheme provides comprehensive support including ₹900 per month for indigenous cow maintenance. Furthermore, it offers ₹20000/ha for vegetable crops. Additionally, the scheme provides natural farming support.',
        'eligibility_criteria': 'The scheme is designed to benefit farmers in gujarat adopting natural farming with indigenous cow.',
        'documents_required': '7/12 & 8-A Land Records, Aadhaar Card, Bank Passbook, Indigenous Cow Certificate',
        'application_link': 'https://naturalfarming.dac.gov.in/FarmerRegistration/FarmarRegist',
        'state_applicability': 'Gujarat',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Organic',
        'required_documents': 'Land docs, Aadhaar, Cow certificate',
    },
    {
        'scheme_id': 'TN_RPS_001',
        'scheme_name': 'Rice Procurement Scheme (Tamil Nadu)',
        'description': 'Paddy procurement at Minimum Support Price',
        'benefits': 'Key benefits of this initiative include msp payment. Furthermore, it offers bonus over msp in some seasons. Additionally, the scheme provides direct procurement by government.',
        'eligibility_criteria': 'Eligibility for this program is extended to paddy farmers in tamil nadu.',
        'documents_required': 'Aadhaar card, Land records, Farmer registration',
        'application_link': 'https://cfpp.nic.in/#/KMS/2025-2026/4/1/33',
        'state_applicability': 'Tamil Nadu',
        'crop_types': 'Paddy',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Financial Support',
        'required_documents': 'Aadhaar, Land docs',
    },
    {
        'scheme_id': 'TN_MI_001',
        'scheme_name': 'Tamil Nadu Micro-Irrigation Scheme',
        'description': 'High subsidy for micro-irrigation systems',
        'benefits': 'Key benefits of this initiative include up to 100% subsidy for small/marginal farmers in some categories. Furthermore, it offers drip and sprinkler irrigation.',
        'eligibility_criteria': 'This scheme is primarily targeted at all farmers in tamil nadu.',
        'documents_required': 'Aadhaar card, Bank account, Land records, Water source proof',
        'application_link': 'https://tnhorticulture.tn.gov.in:8080/Subsidy/ApplySubsidy',
        'state_applicability': 'Tamil Nadu',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Subsidy',
        'required_documents': 'Aadhaar, Bank account, Land docs',
    },
    {
        'scheme_id': 'TN_UZHAVAN_001',
        'scheme_name': 'Uzhavan App Services (Tamil Nadu)',
        'description': 'Integrated mobile application for farmers',
        'benefits': 'This program offers significant advantages such as 17+ services including machinery booking. Furthermore, it offers crop insurance. Additionally, the scheme provides market prices. Moreover, beneficiaries receive real-time advisory.',
        'eligibility_criteria': 'Eligibility for this program is extended to farmers in tamil nadu.',
        'documents_required': 'Mobile number, Aadhaar card',
        'application_link': 'https://play.google.com/store/apps/details?id=com.tnega.uzhavan',
        'state_applicability': 'Tamil Nadu',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Advisory',
        'required_documents': 'Mobile, Aadhaar',
    },
    {
        'scheme_id': 'KER_NADAPU_001',
        'scheme_name': 'Nadapu Scheme (Kerala)',
        'description': 'Organic farming promotion with subsidies',
        'benefits': 'This program offers significant advantages such as subsidies for organic inputs. Furthermore, it offers natural farming support. Additionally, the scheme provides certification assistance.',
        'eligibility_criteria': 'The scheme is designed to benefit organic farmers in kerala.',
        'documents_required': 'Aadhaar card, Bank account, Land records',
        'application_link': 'https://keralaagriculture.gov.in',
        'state_applicability': 'Kerala',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Organic',
        'required_documents': 'Aadhaar, Bank account, Land docs',
    },
    {
        'scheme_id': 'KER_KG_001',
        'scheme_name': 'Keragramam Scheme (Kerala)',
        'description': 'Integrated coconut garden management',
        'benefits': 'Under this scheme, beneficiaries are entitled to subsidy for climbing devices. Furthermore, it offers fertilizers. Additionally, the scheme provides irrigation. Moreover, beneficiaries receive cluster-based approach.',
        'eligibility_criteria': 'Eligibility for this program is extended to coconut farmers in kerala (cluster based).',
        'documents_required': 'Land documents, Bank account, Aadhaar card',
        'application_link': 'https://keralaagriculture.gov.in',
        'state_applicability': 'Kerala',
        'crop_types': 'Coconut',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Production',
        'required_documents': 'Land docs, Bank account, Aadhaar',
    },
    {
        'scheme_id': 'AP_YRB_001',
        'scheme_name': 'YSR Rythu Bharosa (Andhra Pradesh)',
        'description': 'Investment support for farming',
        'benefits': 'This program offers significant advantages such as direct financial assistance per acre. Furthermore, it offers support for inputs.',
        'eligibility_criteria': 'The scheme is designed to benefit land-owning farmers in andhra pradesh.',
        'documents_required': 'Aadhaar card, Bank account, Land records (Pattadar passbook)',
        'application_link': 'https://annadathasukhibhava.ap.gov.in/',
        'state_applicability': 'Andhra Pradesh',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Financial Support',
        'required_documents': 'Aadhaar, Bank account, Pattadar passbook',
    },
    {
        'scheme_id': 'AP_FCIS_001',
        'scheme_name': 'YSR Free Crop Insurance Scheme (AP)',
        'description': 'Zero premium crop insurance',
        'benefits': 'Under this scheme, beneficiaries are entitled to no premium from farmers. Furthermore, it offers natural calamity coverage. Additionally, the scheme provides government pays premium.',
        'eligibility_criteria': 'This scheme is primarily targeted at all farmers in andhra pradesh.',
        'documents_required': 'Aadhaar card, Bank account, Land records',
        'application_link': 'https://www.govtschemes.in/ysr-free-crop-insurance-scheme#google_vignette',
        'state_applicability': 'Andhra Pradesh',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Insurance',
        'required_documents': 'Aadhaar, Bank account, Land docs',
    },
    {
        'scheme_id': 'AP_RBK_001',
        'scheme_name': 'YSR Rythu Bharosa Kendras (AP)',
        'description': 'Village-level input supply centers',
        'benefits': 'Under this scheme, beneficiaries are entitled to quality seeds. Furthermore, it offers fertilizers. Additionally, the scheme provides pesticides at doorstep. Moreover, beneficiaries receive expert advisory. It also aims to ensure one-stop shop.',
        'eligibility_criteria': 'Applicants must fall under the category of all farmers in andhra pradesh.',
        'documents_required': 'Aadhaar card',
        'application_link': 'https://ysrrythubharosa.ap.gov.in/',
        'state_applicability': 'Andhra Pradesh',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Advisory',
        'required_documents': 'Aadhaar',
    },
    {
        'scheme_id': 'PB_PBPK_001',
        'scheme_name': 'Pani Bachao Paise Kamao (Punjab)',
        'description': 'Incentive for saving electricity and water',
        'benefits': 'The scheme provides comprehensive support including direct payment for saved electricity units against quota. Furthermore, it offers water conservation reward.',
        'eligibility_criteria': 'Applicants must fall under the category of farmers with tube wells on specific feeder lines in punjab.',
        'documents_required': 'Electricity connection details, Bank account, Aadhaar card',
        'application_link': 'https://wsstest.pspcl.in/wss/panibachao',
        'state_applicability': 'Punjab',
        'crop_types': 'Rice,Wheat',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Financial Support',
        'required_documents': 'Electricity bill, Bank account, Aadhaar',
    },
    {
        'scheme_id': 'PB_DSR_001',
        'scheme_name': 'Direct Seeded Rice Scheme (Punjab)',
        'description': 'Promotion of water-saving rice cultivation',
        'benefits': 'Under this scheme, beneficiaries are entitled to ₹40000 subsidy per dsr machine. Furthermore, it offers water conservation focus. Additionally, the scheme provides technology adoption support.',
        'eligibility_criteria': 'This scheme is primarily targeted at all rice farmers in punjab.',
        'documents_required': 'Aadhaar card, Bank account, Land records',
        'application_link': 'https://agri.punjab.gov.in/',
        'state_applicability': 'Punjab',
        'crop_types': 'Rice',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Technology',
        'required_documents': 'Aadhaar, Bank account, Land docs',
    },
    {
        'scheme_id': 'TS_MK_001',
        'scheme_name': 'Mission Kakatiya (Telangana)',
        'description': 'Tank restoration and irrigation improvement',
        'benefits': 'Under this scheme, beneficiaries are entitled to restoration of minor irrigation tanks. Furthermore, it offers enhanced water storage. Additionally, the scheme provides increased irrigation area.',
        'eligibility_criteria': 'This scheme is primarily targeted at farmers in ayacut areas of telangana.',
        'documents_required': 'Land documents, Aadhaar card',
        'application_link': 'https://missionkakatiya.cgg.gov.in',
        'state_applicability': 'Telangana',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Infrastructure',
        'required_documents': 'Land docs, Aadhaar',
    },
    {
        'scheme_id': 'OD_MP_001',
        'scheme_name': 'Mo Pokhari (Odisha)',
        'description': 'Farm pond creation for irrigation',
        'benefits': 'Key benefits of this initiative include subsidy up to 50% for farm pond. Furthermore, it offers life-saving irrigation. Additionally, the scheme provides rainwater harvesting.',
        'eligibility_criteria': 'Applicants must fall under the category of farmers in odisha.',
        'documents_required': 'Land Record (RoR), Aadhaar, Bank Passbook',
        'application_link': 'https://agri.odisha.gov.in/en/schemes-agriculture/agriculture?field_agriculture_sector_and_sch_target_id=2623',
        'state_applicability': 'Odisha',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Infrastructure',
        'required_documents': 'Land records, Aadhaar, Bank passbook',
    },
    {
        'scheme_id': 'OD_BALARAM_001',
        'scheme_name': 'Balaram Yojana (Odisha)',
        'description': 'River lift irrigation and groundwater support',
        'benefits': 'This program offers significant advantages such as river lift irrigation projects. Furthermore, it offers groundwater irrigation support. Additionally, the scheme provides irrigation infrastructure.',
        'eligibility_criteria': 'Eligibility for this program is extended to farmers in odisha.',
        'documents_required': 'Land records, Aadhaar card, Bank account',
        'application_link': 'https://agri.odisha.gov.in/en/schemes-agriculture/agriculture/BALARAM',
        'state_applicability': 'Odisha',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Infrastructure',
        'required_documents': 'Land docs, Aadhaar, Bank account',
    },
    {
        'scheme_id': 'MP_BBY_001',
        'scheme_name': 'Bhavantar Bhugtan Yojana (MP)',
        'description': 'Price deficiency payment scheme',
        'benefits': 'The scheme provides comprehensive support including direct payment of price difference between msp and modal rate. Furthermore, it offers bank transfer.',
        'eligibility_criteria': 'Applicants must fall under the category of farmers in mp selling notified crops.',
        'documents_required': 'Mandi sale receipt, Aadhaar, Bank account, Registration',
        'application_link': 'https://mpkrishi.mp.gov.in',
        'state_applicability': 'Madhya Pradesh',
        'crop_types': 'Pulses,Oilseeds,Maize',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Financial Support',
        'required_documents': 'Sale receipt, Aadhaar, Registration',
    },
    {
        'scheme_id': 'RAJ_SOLAR_001',
        'scheme_name': 'Rajasthan Solar Pump Scheme',
        'description': 'Solar irrigation pump subsidy',
        'benefits': 'The scheme provides comprehensive support including 90% subsidy for small farmers. Furthermore, it offers clean energy promotion. Additionally, the scheme provides reduced electricity cost.',
        'eligibility_criteria': 'Eligibility for this program is extended to small and marginal farmers in rajasthan.',
        'documents_required': 'Aadhaar card, Bank account, Land records',
        'application_link': 'https://rajkisan.rajasthan.gov.in/',
        'state_applicability': 'Rajasthan',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal',
        'scheme_type': 'Subsidy',
        'required_documents': 'Aadhaar, Bank account, Land docs',
    },
    {
        'scheme_id': 'RAJ_DRIP_001',
        'scheme_name': 'Rajasthan Drip Irrigation Subsidy',
        'description': 'Subsidy for drip irrigation systems',
        'benefits': 'The scheme provides comprehensive support including up to 70% in drought-prone areas. Furthermore, it offers 50% in other areas. Additionally, the scheme provides water conservation.',
        'eligibility_criteria': 'Applicants must fall under the category of all farmers in rajasthan.',
        'documents_required': 'Aadhaar card, Bank account, Land records, Water source proof',
        'application_link': 'https://rajkisan.rajasthan.gov.in/WebsiteNew/dripirrigation.html',
        'state_applicability': 'Rajasthan',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Subsidy',
        'required_documents': 'Aadhaar, Bank account, Land docs',
    },
    {
        'scheme_id': 'HP_HKY_001',
        'scheme_name': 'Him Krishi Yojana (Himachal Pradesh)',
        'description': 'Cluster-based agricultural development',
        'benefits': 'The scheme provides comprehensive support including horticulture focus. Furthermore, it offers cluster development. Additionally, the scheme provides technology adoption.',
        'eligibility_criteria': 'The scheme is designed to benefit farmers in hp.',
        'documents_required': 'Aadhaar card, Bank account, Land records',
        'application_link': 'https://agriculture.hp.gov.in',
        'state_applicability': 'Himachal Pradesh',
        'crop_types': 'Fruits,Vegetables,Horticulture',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Production',
        'required_documents': 'Aadhaar, Bank account, Land docs',
    },
    {
        'scheme_id': 'HP_SSY_001',
        'scheme_name': 'Saur Sinchai Yojana (HP)',
        'description': 'Solar irrigation scheme',
        'benefits': 'Under this scheme, beneficiaries are entitled to 90% subsidy for small/marginal farmers. Furthermore, it offers 80% for medium/large farmers. Additionally, the scheme provides solar pump installation.',
        'eligibility_criteria': 'Eligibility for this program is extended to all farmers in himachal pradesh.',
        'documents_required': 'Aadhaar card, Bank account, Land records',
        'application_link': 'https://www.apnikheti.com/en/pn/govt-schemes-details/saur-sinchai-yojana',
        'state_applicability': 'Himachal Pradesh',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Subsidy',
        'required_documents': 'Aadhaar, Bank account, Land docs',
    },
    {
        'scheme_id': 'UK_NMMI_001',
        'scheme_name': 'NMMI Uttarakhand',
        'description': 'Micro-irrigation mission for hill agriculture',
        'benefits': 'Under this scheme, beneficiaries are entitled to 50% subsidy for small/marginal farmers. Furthermore, it offers 40% for others. Additionally, the scheme provides special equipment for hilly terrain.',
        'eligibility_criteria': 'Eligibility for this program is extended to all farmers in uttarakhand.',
        'documents_required': 'Aadhaar card, Bank account, Land records',
        'application_link': 'https://agriculture.uk.gov.in',
        'state_applicability': 'Uttarakhand',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Subsidy',
        'required_documents': 'Aadhaar, Bank account, Land docs',
    },
    {
        'scheme_id': 'CG_RGKNY_001',
        'scheme_name': 'Rajiv Gandhi Kisan Nyay Yojana (Chhattisgarh)',
        'description': 'Input cost support scheme',
        'benefits': 'Key benefits of this initiative include per acre financial assistance. Furthermore, it offers direct cash transfer. Additionally, the scheme provides support for farming inputs.',
        'eligibility_criteria': 'Applicants must fall under the category of all farmers in chhattisgarh.',
        'documents_required': 'Aadhaar card, Bank account, Land records',
        'application_link': 'https://kisan.cg.nic.in/',
        'state_applicability': 'Chhattisgarh',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Financial Support',
        'required_documents': 'Aadhaar, Bank account, Land docs',
    },
    {
        'scheme_id': 'CG_GODHAN_001',
        'scheme_name': 'Godhan Nyay Yojana (Chhattisgarh)',
        'description': 'Cow dung purchase scheme',
        'benefits': 'The scheme provides comprehensive support including government purchases cow dung at ₹2/kg. Furthermore, it offers organic manure production. Additionally, the scheme provides additional income source.',
        'eligibility_criteria': 'Eligibility for this program is extended to cattle owners in chhattisgarh.',
        'documents_required': 'Aadhaar card',
        'application_link': 'https://agriportal.cg.nic.in/',
        'state_applicability': 'Chhattisgarh',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Financial Support',
        'required_documents': 'Aadhaar',
    },
    {
        'scheme_id': 'ASSAM_MKSSY_001',
        'scheme_name': 'Mukhya Mantri Krishi Sa-Sajuli Yojana (Assam)',
        'description': 'Farm mechanization scheme',
        'benefits': 'This program offers significant advantages such as 80% subsidy on farm equipment. Furthermore, it offers focus on small farmers. Additionally, the scheme provides technology adoption.',
        'eligibility_criteria': 'This scheme is primarily targeted at small farmers in assam.',
        'documents_required': 'Aadhaar card, Bank account, Land records',
        'application_link': 'https://agri-horti.assam.gov.in',
        'state_applicability': 'Assam',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal',
        'scheme_type': 'Technology',
        'required_documents': 'Aadhaar, Bank account, Land docs',
    },
    {
        'scheme_id': 'JH_BGVY_001',
        'scheme_name': 'Birsa Harit Gram Yojana (Jharkhand)',
        'description': 'Integrated watershed development',
        'benefits': 'This program offers significant advantages such as watershed development. Furthermore, it offers livelihood enhancement. Additionally, the scheme provides integrated farming.',
        'eligibility_criteria': 'Applicants must fall under the category of farmers in jharkhand.',
        'documents_required': 'Aadhaar card, Bank account, Land records',
        'application_link': 'https://www.jharkhand.gov.in/agriculture',
        'state_applicability': 'Jharkhand',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Sustainability',
        'required_documents': 'Aadhaar, Bank account, Land docs',
    },
    {
        'scheme_id': 'MOVCD_001',
        'scheme_name': 'Mission Organic Value Chain Development for North Eastern Region',
        'description': 'Organic farming promotion in NE states',
        'benefits': 'Key benefits of this initiative include organic certification support. Furthermore, it offers market linkages. Additionally, the scheme provides cluster-based approach. Moreover, beneficiaries receive value chain development.',
        'eligibility_criteria': 'Eligibility for this program is extended to farmers in north-east states.',
        'documents_required': 'Aadhaar card, Bank account, Land records',
        'application_link': 'https://agriculture.nagaland.gov.in/movcd/',
        'state_applicability': 'Arunachal Pradesh, Assam, Manipur, Meghalaya, Mizoram, Nagaland, Sikkim, Tripura',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Organic',
        'required_documents': 'Aadhaar, Bank account, Land docs',
    },
    {
        'scheme_id': 'NHB_001',
        'scheme_name': 'National Horticulture Board Schemes',
        'description': 'Comprehensive horticulture development',
        'benefits': 'Key benefits of this initiative include area expansion. Furthermore, it offers protected cultivation. Additionally, the scheme provides post-harvest management. Moreover, beneficiaries receive technology demonstration.',
        'eligibility_criteria': 'Eligibility for this program is extended to horticulture farmers nationwide.',
        'documents_required': 'Aadhaar card, Bank account, Land records, Project proposal',
        'application_link': 'https://nhb.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'Fruits,Vegetables,Flowers,Spices',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Production',
        'required_documents': 'Aadhaar, Bank account, Project proposal',
    },
    {
        'scheme_id': 'VANILLA_001',
        'scheme_name': 'Vanilla Promotion Scheme',
        'description': 'Promotion of vanilla cultivation',
        'benefits': 'Under this scheme, beneficiaries are entitled to subsidy for planting material. Furthermore, it offers curing sheds. Additionally, the scheme provides market linkage. Moreover, beneficiaries receive technical support.',
        'eligibility_criteria': 'Eligibility for this program is extended to farmers in kerala. The scheme also covers karnataka. It is applicable to tamil nadu.',
        'documents_required': 'Land documents, Spices Board registration, Aadhaar',
        'application_link': 'https://pmfme.mofpi.gov.in/pmfme/#/Register-New-User',
        'state_applicability': 'All States',
        'crop_types': 'Vanilla',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Production',
        'required_documents': 'Land docs, Spices Board registration',
    },
    {
        'scheme_id': 'FLOR_001',
        'scheme_name': 'Commercial Floriculture Scheme',
        'description': 'Promotion of commercial flower cultivation',
        'benefits': 'The scheme provides comprehensive support including subsidy for polyhouse. Furthermore, it offers planting material. Additionally, the scheme provides protected cultivation. Moreover, beneficiaries receive market access.',
        'eligibility_criteria': 'The scheme is designed to benefit floriculture farmers.',
        'documents_required': 'Land documents, Project report, Aadhaar, Bank account',
        'application_link': 'https://nhb.gov.in/highlights/application-form-for-LOI.html',
        'state_applicability': 'All States',
        'crop_types': 'Floriculture,Rose,Gerbera,Carnation',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Production',
        'required_documents': 'Land docs, Project report, Aadhaar',
    },
    {
        'scheme_id': 'APPLE_001',
        'scheme_name': 'Apple High Density Plantation',
        'description': 'Promotion of high density apple orchards',
        'benefits': 'Under this scheme, beneficiaries are entitled to subsidy for imported rootstocks. Furthermore, it offers trellis system. Additionally, the scheme provides higher productivity technology.',
        'eligibility_criteria': 'The scheme is designed to benefit apple growers in j&k. The scheme also covers hp. It is applicable to uttarakhand.',
        'documents_required': 'Land documents, Orchard details, Aadhaar, Bank account',
        'application_link': 'https://horticulture.jk.gov.in/pdf/HDAP-Scheme.pdf',
        'state_applicability': 'All States',
        'crop_types': 'Apple',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Production',
        'required_documents': 'Land docs, Orchard details, Aadhaar',
    },
    {
        'scheme_id': 'CITRUS_001',
        'scheme_name': 'Citrus Development Scheme',
        'description': 'Expansion of citrus fruits cultivation',
        'benefits': 'Key benefits of this initiative include subsidy for planting material. Furthermore, it offers high-density planting. Additionally, the scheme provides integrated pest management.',
        'eligibility_criteria': 'Eligibility for this program is extended to citrus growers.',
        'documents_required': 'Land documents, Bank account, Aadhaar',
        'application_link': 'https://nhb.gov.in/OnlineApplication/Online_Registration_Intermediate_Page.aspx',
        'state_applicability': 'All States',
        'crop_types': 'Citrus,Orange,Lemon,Lime',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Production',
        'required_documents': 'Land docs, Bank account, Aadhaar',
    },
    {
        'scheme_id': 'MILLET_001',
        'scheme_name': 'National Mission on Millets',
        'description': 'Promotion of millets for nutritional security',
        'benefits': 'This program offers significant advantages such as incentives for production. Furthermore, it offers processing support. Additionally, the scheme provides value addition. Moreover, beneficiaries receive market linkage.',
        'eligibility_criteria': 'Applicants must fall under the category of millet farmers.',
        'documents_required': 'Land documents, Bank account, Aadhaar',
        'application_link': 'https://nfsm.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'Millets,Bajra,Jowar,Ragi',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Production',
        'required_documents': 'Land docs, Bank account, Aadhaar',
    },
    {
        'scheme_id': 'COCONUT_001',
        'scheme_name': 'Coconut Development Board Schemes',
        'description': 'Comprehensive coconut development',
        'benefits': 'Under this scheme, beneficiaries are entitled to productivity enhancement. Furthermore, it offers market development. Additionally, the scheme provides technology demonstrations. Moreover, beneficiaries receive processing support.',
        'eligibility_criteria': 'This scheme is primarily targeted at coconut farmers.',
        'documents_required': 'Aadhaar card, Bank account, Land records',
        'application_link': 'https://coconutboard.gov.in/ApplicationForms.aspx#aep',
        'state_applicability': 'All States',
        'crop_types': 'Coconut',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Production',
        'required_documents': 'Aadhaar, Bank account, Land docs',
    },
    {
        'scheme_id': 'RUBBER_001',
        'scheme_name': 'Rubber Board Schemes',
        'description': 'Support for rubber cultivation',
        'benefits': 'Key benefits of this initiative include subsidy for new planting. Furthermore, it offers replanting. Additionally, the scheme provides technology adoption. Moreover, beneficiaries receive market information.',
        'eligibility_criteria': 'This scheme is primarily targeted at rubber growers.',
        'documents_required': 'Aadhaar card, Bank account, Land records',
        'application_link': 'https://rubberboard.gov.in/menuview',
        'state_applicability': 'All States',
        'crop_types': 'Rubber',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Production',
        'required_documents': 'Aadhaar, Bank account, Land docs',
    },
    {
        'scheme_id': 'TEA_001',
        'scheme_name': 'Tea Board Schemes',
        'description': 'Development of tea sector',
        'benefits': 'Under this scheme, beneficiaries are entitled to subsidy for new planting. Furthermore, it offers replanting. Additionally, the scheme provides quality improvement. Moreover, beneficiaries receive market promotion.',
        'eligibility_criteria': 'Eligibility for this program is extended to tea growers.',
        'documents_required': 'Aadhaar card, Bank account, Land records, Tea garden registration',
        'application_link': 'https://onlineapps.teaboard.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'Tea',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Production',
        'required_documents': 'Aadhaar, Registration certificate',
    },
    {
        'scheme_id': 'COFFEE_001',
        'scheme_name': 'Coffee Board Schemes',
        'description': 'Comprehensive coffee development',
        'benefits': 'The scheme provides comprehensive support including subsidy for new planting. Furthermore, it offers replanting. Additionally, the scheme provides processing equipment. Moreover, beneficiaries receive quality certification.',
        'eligibility_criteria': 'This scheme is primarily targeted at coffee growers.',
        'documents_required': 'Aadhaar card, Bank account, Land records, Grower registration',
        'application_link': 'https://coffeeboard.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'Coffee',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Production',
        'required_documents': 'Aadhaar, Grower registration',
    },
    {
        'scheme_id': 'NHM_001',
        'scheme_name': 'National Horticulture Mission',
        'description': 'Holistic horticulture development',
        'benefits': 'Under this scheme, beneficiaries are entitled to area expansion. Furthermore, it offers protected cultivation. Additionally, the scheme provides post-harvest infrastructure. Moreover, beneficiaries receive market development.',
        'eligibility_criteria': 'The scheme is designed to benefit all horticulture farmers.',
        'documents_required': 'Aadhaar card, Bank account, Land records',
        'application_link': 'https://www.myscheme.gov.in/schemes/midh',
        'state_applicability': 'All States',
        'crop_types': 'Fruits,Vegetables,Flowers',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Production',
        'required_documents': 'Aadhaar, Bank account, Land docs',
    },
    {
        'scheme_id': 'NLM_001',
        'scheme_name': 'National Livestock Mission',
        'description': 'Livestock development and productivity enhancement',
        'benefits': 'Under this scheme, beneficiaries are entitled to breed improvement. Furthermore, it offers fodder development. Additionally, the scheme provides skill development. Moreover, beneficiaries receive risk coverage.',
        'eligibility_criteria': 'The scheme is designed to benefit livestock farmers.',
        'documents_required': 'Aadhaar card, Bank account, Animal registration (if applicable)',
        'application_link': 'https://nlm.udyamimitra.in/Home/PreApplication',
        'state_applicability': 'All States',
        'crop_types': 'Livestock',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Allied Sector',
        'required_documents': 'Aadhaar, Bank account',
    },
    {
        'scheme_id': 'RGM_001',
        'scheme_name': 'Rashtriya Gokul Mission',
        'description': 'Indigenous cattle breed conservation and development',
        'benefits': 'This program offers significant advantages such as breed conservation. Furthermore, it offers productivity enhancement. Additionally, the scheme provides gokul grams establishment. Moreover, beneficiaries receive breed multiplication.',
        'eligibility_criteria': 'This scheme is primarily targeted at cattle farmers.',
        'documents_required': 'Aadhaar card, Bank account, Animal details',
        'application_link': 'https://dahd.gov.in/schemes/programmes/rashtriya_gokul_mission',
        'state_applicability': 'All States',
        'crop_types': 'Cattle',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Allied Sector',
        'required_documents': 'Aadhaar, Bank account',
    },
    {
        'scheme_id': 'DAIRY_001',
        'scheme_name': 'Dairy Entrepreneurship Development Scheme',
        'description': 'Promotion of dairy entrepreneurship',
        'benefits': 'Key benefits of this initiative include subsidy for dairy units. Furthermore, it offers loan assistance. Additionally, the scheme provides technology support. Moreover, beneficiaries receive market linkage.',
        'eligibility_criteria': 'Eligibility for this program is extended to farmers. The scheme also covers dairy entrepreneurs.',
        'documents_required': 'Aadhaar card, Bank account, Project proposal',
        'application_link': 'https://dahvs.odisha.gov.in/dairy-development/',
        'state_applicability': 'All States',
        'crop_types': 'Dairy',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Allied Sector',
        'required_documents': 'Aadhaar, Project proposal',
    },
    {
        'scheme_id': 'POULTRY_001',
        'scheme_name': 'Poultry Venture Capital Fund',
        'description': 'Support for poultry farming',
        'benefits': 'Key benefits of this initiative include financial assistance for poultry units. Furthermore, it offers subsidy support. Additionally, the scheme provides technical guidance.',
        'eligibility_criteria': 'This scheme is primarily targeted at farmers. The scheme also covers entrepreneurs.',
        'documents_required': 'Aadhaar card, Bank account, Project report',
        'application_link': 'https://nlm.udyamimitra.in/Login/AgencyRegistration',
        'state_applicability': 'All States',
        'crop_types': 'Poultry',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Allied Sector',
        'required_documents': 'Aadhaar, Project report',
    },
    {
        'scheme_id': 'SUFAL_BANGLA_001',
        'scheme_name': 'Sufal Bangla (West Bengal)',
        'description': 'Vegetable marketing and cold chain',
        'benefits': 'Key benefits of this initiative include cold storage. Furthermore, it offers marketing infrastructure. Additionally, the scheme provides fair price to farmers. Moreover, beneficiaries receive retail outlets.',
        'eligibility_criteria': 'Eligibility for this program is extended to vegetable farmers in west bengal.',
        'documents_required': 'Aadhaar card, Bank account, Farmer registration',
        'application_link': 'https://wb.gov.in/',
        'state_applicability': 'West Bengal',
        'crop_types': 'Vegetables',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Market Access',
        'required_documents': 'Aadhaar, Farmer registration',
    },
    {
        'scheme_id': 'KRUSHAK_PORTAL_001',
        'scheme_name': 'Krushak Odisha Portal',
        'description': 'Unified farmer registration and scheme access',
        'benefits': 'This program offers significant advantages such as single registration for all schemes. Furthermore, it offers input procurement. Additionally, the scheme provides scheme benefits tracking.',
        'eligibility_criteria': 'This scheme is primarily targeted at all farmers in odisha.',
        'documents_required': 'Aadhaar card, Mobile number, Bank account',
        'application_link': 'https://cmkportal.odisha.gov.in/Farmer/Registration',
        'state_applicability': 'Odisha',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Technology',
        'required_documents': 'Aadhaar, Mobile, Bank account',
    },
    {
        'scheme_id': 'KAR_SANJEEVINI_001',
        'scheme_name': 'Sanjeevini Scheme (Karnataka)',
        'description': 'Free power supply for agriculture',
        'benefits': 'This program offers significant advantages such as free electricity for agricultural pumpsets. Furthermore, it offers scheduled power supply. Additionally, the scheme provides subsidy benefit.',
        'eligibility_criteria': 'This scheme is primarily targeted at farmers with pumpsets in karnataka.',
        'documents_required': 'Electricity connection details, Aadhaar card, Land records',
        'application_link': 'https://kass.karnataka.gov.in/42/beneficiary-enrolment/en',
        'state_applicability': 'Karnataka',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Subsidy',
        'required_documents': 'Electricity connection, Aadhaar',
    },
    {
        'scheme_id': 'KAR_BHOOCHETANA_001',
        'scheme_name': 'Bhoochetana Scheme (Karnataka)',
        'description': 'Soil health improvement program',
        'benefits': 'The scheme provides comprehensive support including soil testing. Furthermore, it offers micronutrient application. Additionally, the scheme provides balanced fertilization. Moreover, beneficiaries receive yield improvement.',
        'eligibility_criteria': 'Eligibility for this program is extended to all farmers in karnataka.',
        'documents_required': 'Aadhaar card, Land records',
        'application_link': 'https://swdcorp.karnataka.gov.in/ADCLPortal/schemedetail/LPS',
        'state_applicability': 'Karnataka',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Advisory',
        'required_documents': 'Aadhaar, Land docs',
    },
    {
        'scheme_id': 'KAR_RVN_001',
        'scheme_name': 'Raitha Vidya Nidhi (Karnataka)',
        'description': 'Scholarship for farmers\' children',
        'benefits': 'The scheme provides comprehensive support including annual scholarship ₹2500 to ₹11000. Furthermore, it offers encourage higher education. Additionally, the scheme provides support for students.',
        'eligibility_criteria': 'Applicants must fall under the category of children of registered farmers in karnataka.',
        'documents_required': 'Student ID, Farmer ID of parent, Aadhaar, Educational certificates',
        'application_link': 'https://yuvakanaja.in/agriculture-en/raita-vidyanidhi-yojana/',
        'state_applicability': 'Karnataka',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Financial Support',
        'required_documents': 'Student ID, Farmer ID, Education docs',
    },
    {
        'scheme_id': 'TN_ZERO_TILL_001',
        'scheme_name': 'Zero-Till Cultivation Incentive (Tamil Nadu)',
        'description': 'Conservation agriculture promotion',
        'benefits': 'Key benefits of this initiative include equipment subsidy. Furthermore, it offers reduced tillage benefits. Additionally, the scheme provides soil health improvement.',
        'eligibility_criteria': 'This scheme is primarily targeted at farmers in tamil nadu.',
        'documents_required': 'Aadhaar card, Bank account, Land records',
        'application_link': 'https://tnfr.agristack.gov.in/farmer-registry-tn/#/',
        'state_applicability': 'Tamil Nadu',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Technology',
        'required_documents': 'Aadhaar, Bank account, Land docs',
    },
    {
        'scheme_id': 'TN_FARM_POND_001',
        'scheme_name': 'Farm Pond Scheme (Tamil Nadu)',
        'description': 'Rainwater harvesting structures',
        'benefits': 'This program offers significant advantages such as subsidy for farm pond construction. Furthermore, it offers water conservation. Additionally, the scheme provides life-saving irrigation.',
        'eligibility_criteria': 'This scheme is primarily targeted at all farmers in tamil nadu.',
        'documents_required': 'Aadhaar card, Bank account, Land records',
        'application_link': 'https://tnhorticulture.tn.gov.in/tnhortnet/scheme-registration',
        'state_applicability': 'Tamil Nadu',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Infrastructure',
        'required_documents': 'Aadhaar, Bank account, Land docs',
    },
    {
        'scheme_id': 'MYSCHEME_001',
        'scheme_name': 'myScheme Portal',
        'description': 'Unified government schemes discovery portal',
        'benefits': 'Key benefits of this initiative include search schemes by eligibility. Furthermore, it offers centralized information. Additionally, the scheme provides multiple scheme access. Moreover, beneficiaries receive direct links.',
        'eligibility_criteria': 'Eligibility for this program is extended to all citizens including farmers.',
        'documents_required': 'Basic details for eligibility check',
        'application_link': 'https://www.myscheme.gov.in',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Technology',
        'required_documents': 'Basic details',
    },
    {
        'scheme_id': 'UMANG_001',
        'scheme_name': 'UMANG App',
        'description': 'Unified Mobile Application for New-age Governance',
        'benefits': 'Under this scheme, beneficiaries are entitled to access to multiple government services. Furthermore, it offers agriculture schemes. Additionally, the scheme provides direct applications. Moreover, beneficiaries receive status tracking.',
        'eligibility_criteria': 'The scheme is designed to benefit all citizens including farmers.',
        'documents_required': 'Smartphone, Aadhaar for registration',
        'application_link': 'https://play.google.com/store/apps/details?id=in.gov.umang.negd.g2c',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Technology',
        'required_documents': 'Smartphone, Aadhaar',
    },
    {
        'scheme_id': 'KISAN_RATH_001',
        'scheme_name': 'Kisan Rath Mobile App',
        'description': 'Transportation solution for agricultural produce',
        'benefits': 'Under this scheme, beneficiaries are entitled to connect farmers with transporters. Furthermore, it offers fair pricing. Additionally, the scheme provides reduced wastage. Moreover, beneficiaries receive quick transport.',
        'eligibility_criteria': 'Eligibility for this program is extended to all farmers.',
        'documents_required': 'Mobile phone, Registration details',
        'application_link': 'https://play.google.com/store/apps/details?id=com.nic.kisanrath',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Market Access',
        'required_documents': 'Mobile phone',
    },
    {
        'scheme_id': 'ENAM_MOBILE_001',
        'scheme_name': 'e-NAM Mobile App',
        'description': 'Mobile application for national agriculture market',
        'benefits': 'The scheme provides comprehensive support including mobile trading. Furthermore, it offers price discovery. Additionally, the scheme provides market information. Moreover, beneficiaries receive bidding facility.',
        'eligibility_criteria': 'This scheme is primarily targeted at registered farmers on e-nam.',
        'documents_required': 'Smartphone, e-NAM registration',
        'application_link': 'https://play.google.com/store/apps/details?id=in.gov.enam',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Market Access',
        'required_documents': 'Smartphone, e-NAM registration',
    },
    {
        'scheme_id': 'AGMARKNET_001',
        'scheme_name': 'AGMARKNET',
        'description': 'Agricultural marketing information network',
        'benefits': 'This program offers significant advantages such as daily market prices. Furthermore, it offers arrival data. Additionally, the scheme provides commodity prices across mandis. Moreover, beneficiaries receive market trends.',
        'eligibility_criteria': 'This scheme is primarily targeted at all farmers.',
        'documents_required': 'Internet access',
        'application_link': 'https://agmarknet.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Advisory',
        'required_documents': 'Internet access',
    },
    {
        'scheme_id': 'NBHM_BEE_001',
        'scheme_name': 'National Beekeeping & Honey Mission - Beehive Support',
        'description': 'Financial assistance for establishing bee colonies and honey production',
        'benefits': 'Key benefits of this initiative include 100% assistance for public sector. Furthermore, it offers 50% subsidy up to ₹3 lakh for private sector. Additionally, the scheme provides released in 3 installments (50%. Moreover, beneficiaries receive 25%. It also aims to ensure 25%).',
        'eligibility_criteria': 'Applicants must fall under the category of farmers. The scheme also covers fpos. It is applicable to shgs. Furthermore, eligibility extends to cooperatives. Additionally, it includes entrepreneurs in scientific beekeeping.',
        'documents_required': 'Aadhaar card, Bank account, Training certificate, Land documents',
        'application_link': 'https://madhukranti.in/NBB/frm_registration_new.aspx',
        'state_applicability': 'All States',
        'crop_types': 'All Crops - Beekeeping',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Allied Sector',
        'required_documents': 'Aadhaar, Training cert, Land docs',
    },
    {
        'scheme_id': 'SWEET_KRANTI_001',
        'scheme_name': 'Sweet Kranti (Honey Mission) - KVIC',
        'description': 'Promotion of beekeeping for honey production and rural livelihood',
        'benefits': 'Key benefits of this initiative include training support. Furthermore, it offers subsidy for bee colonies. Additionally, the scheme provides equipment support. Moreover, beneficiaries receive market linkage. It also aims to ensure backward linkage support.',
        'eligibility_criteria': 'The scheme is designed to benefit adivasis. The scheme also covers farmers. It is applicable to unemployed youth. Furthermore, eligibility extends to women. Additionally, it includes rural communities.',
        'documents_required': 'Aadhaar card, Training participation certificate',
        'application_link': 'https://kvic.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'Beekeeping',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Allied Sector',
        'required_documents': 'Aadhaar',
    },
    {
        'scheme_id': 'HP_MADHU_001',
        'scheme_name': 'Mukhyamantri Madhu Vikas Yojana (HP)',
        'description': 'Beekeeping promotion in Himachal Pradesh',
        'benefits': 'The scheme provides comprehensive support including 80% subsidy for up to 50 bee colonies per beneficiary. Furthermore, it offers training programs. Additionally, the scheme provides equipment subsidies. Moreover, beneficiaries receive transportation support.',
        'eligibility_criteria': 'Applicants must fall under the category of residents of himachal pradesh. The scheme also covers unemployed youth. It is applicable to farmers.',
        'documents_required': 'Aadhaar card, Residence proof, Bank account',
        'application_link': 'https://agriculture.hp.gov.in',
        'state_applicability': 'Himachal Pradesh',
        'crop_types': 'Beekeeping',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Allied Sector',
        'required_documents': 'Aadhaar, Residence proof',
    },
    {
        'scheme_id': 'MIDH_MUSH_001',
        'scheme_name': 'MIDH - Mushroom Production Units',
        'description': 'Support for mushroom cultivation and compost making units',
        'benefits': 'Under this scheme, beneficiaries are entitled to ₹20 lakh for production and compost units. Furthermore, it offers ₹15 lakh for spawn units. Additionally, the scheme provides 100% for public sector. Moreover, beneficiaries receive 40% for private.',
        'eligibility_criteria': 'Eligibility for this program is extended to farmers. The scheme also covers shgs. It is applicable to fpos. Furthermore, eligibility extends to entrepreneurs in mushroom farming.',
        'documents_required': 'Aadhaar card, Bank account, Project proposal, Training certificate',
        'application_link': 'https://megedistrict.gov.in/viewServiceApplicationForm.do',
        'state_applicability': 'All States',
        'crop_types': 'Mushroom',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Production',
        'required_documents': 'Aadhaar, Project proposal',
    },
    {
        'scheme_id': 'RKVY_MUSH_001',
        'scheme_name': 'RKVY - Oyster Mushroom Promotion',
        'description': 'Promotion of oyster mushroom farming especially for women farmers',
        'benefits': 'Under this scheme, beneficiaries are entitled to financial support for 500 units in 14 districts. Furthermore, it offers training at kvks. Additionally, the scheme provides minimal investment required.',
        'eligibility_criteria': 'This scheme is primarily targeted at small farmers. The scheme also covers marginal farmers. It is applicable to landless laborers. Furthermore, eligibility extends to women shgs.',
        'documents_required': 'Aadhaar card, SHG membership (if applicable), Training certificate',
        'application_link': 'https://rkvy.nic.in/',
        'state_applicability': 'All States',
        'crop_types': 'Oyster Mushroom',
        'farmer_category': 'Small,Marginal',
        'scheme_type': 'Production',
        'required_documents': 'Aadhaar',
    },
    {
        'scheme_id': 'WIF_001',
        'scheme_name': 'Warehouse Infrastructure Fund - NABARD',
        'description': 'Credit for construction of warehouses silos cold storage for agricultural commodities',
        'benefits': 'Key benefits of this initiative include nabard loans for minimum 5000 mt capacity. Furthermore, it offers low interest rates. Additionally, the scheme provides long repayment period.',
        'eligibility_criteria': 'This scheme is primarily targeted at public sector. The scheme also covers private sector. It is applicable to pacs. Furthermore, eligibility extends to cooperatives. Additionally, it includes fpos, and individuals.',
        'documents_required': 'Project report, Land documents, Registration certificates, Financial statements',
        'application_link': 'https://kipfinancial.com/nabard-subsidy-on-warehouse/#',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Infrastructure',
        'required_documents': 'Project report, Land docs, Financial statements',
    },
    {
        'scheme_id': 'PMKSY_SAMPADA_001',
        'scheme_name': 'PM Kisan SAMPADA Yojana',
        'description': 'Modern infrastructure for food processing sector from farm to retail',
        'benefits': 'Under this scheme, beneficiaries are entitled to processing capacity 255. 66 lmt/year. Furthermore, it offers 1601 projects approved. Additionally, the scheme provides cold chain infrastructure. Moreover, beneficiaries receive post-harvest management.',
        'eligibility_criteria': 'Applicants must fall under the category of farmers. The scheme also covers fpos. It is applicable to food processing units. Furthermore, eligibility extends to entrepreneurs.',
        'documents_required': 'Project proposal, Registration documents, Bank account, Land documents',
        'application_link': 'https://www.mofpi.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'All Crops - Food Processing',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Infrastructure',
        'required_documents': 'Project proposal, Registration docs',
    },
    {
        'scheme_id': 'CAP_SUBSIDY_001',
        'scheme_name': 'Capital Investment Subsidy for Cold Storage',
        'description': 'Subsidy for cold storage projects to promote scientific storage',
        'benefits': 'The scheme provides comprehensive support including 35-50% subsidy for cold storage projects. Furthermore, it offers support for perishable commodities. Additionally, the scheme provides modern infrastructure.',
        'eligibility_criteria': 'Eligibility for this program is extended to individuals. The scheme also covers companies. It is applicable to fpos. Furthermore, eligibility extends to cooperatives establishing cold storage.',
        'documents_required': 'Project report, Registration documents, Bank account, Technical clearance',
        'application_link': 'https://www.mofpi.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'Fruits,Vegetables,Horticulture',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Infrastructure',
        'required_documents': 'Project report, Technical clearance',
    },
    {
        'scheme_id': 'PACS_STORAGE_001',
        'scheme_name': 'PACS Computerization & Storage Development',
        'description': 'Village-level storage through computerized PACS',
        'benefits': 'This program offers significant advantages such as ₹2516 crore for computerization. Furthermore, it offers 73492 pacs computerized. Additionally, the scheme provides 500-2000 mt capacity. Moreover, beneficiaries receive decentralized storage.',
        'eligibility_criteria': 'Applicants must fall under the category of primary agricultural credit societies (pacs).',
        'documents_required': 'PACS registration, Computerization certification',
        'application_link': 'https://cooperation.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Infrastructure',
        'required_documents': 'PACS registration',
    },
    {
        'scheme_id': 'WLGSP_001',
        'scheme_name': 'World\'s Largest Grain Storage Plan - Cooperative Sector',
        'description': 'Decentralized grain storage through PACS with ownership model',
        'benefits': 'Key benefits of this initiative include 9-year fci rental guarantee for 2500+ mt capacity. Furthermore, it offers 2+8 year loan repayment. Additionally, the scheme provides infrastructure subsidy. Moreover, beneficiaries receive road and weighing support.',
        'eligibility_criteria': 'Eligibility for this program is extended to pacs. The scheme also covers cooperative societies. It is applicable to village-level storage units.',
        'documents_required': 'PACS registration, Project proposal, Land documents, Membership records',
        'application_link': 'https://www.cooperation.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'Foodgrains',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Infrastructure',
        'required_documents': 'PACS registration, Project proposal',
    },
    {
        'scheme_id': 'WDC_PMKSY_001',
        'scheme_name': 'Watershed Development Component - PMKSY 2.0',
        'description': 'Integrated watershed management for rainfed areas',
        'benefits': 'Key benefits of this initiative include ₹49. 50 lakh hectares target (2021-2026). Furthermore, it offers soil and water conservation. Additionally, the scheme provides climate resilient agriculture. Moreover, beneficiaries receive livelihood enhancement.',
        'eligibility_criteria': 'Eligibility for this program is extended to farmers in rainfed/watershed areas.',
        'documents_required': 'Aadhaar card, Land records, Watershed committee membership',
        'application_link': 'https://pmksy.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'All Crops - Rainfed',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Sustainability',
        'required_documents': 'Aadhaar, Land records',
    },
    {
        'scheme_id': 'REWARD_001',
        'scheme_name': 'Rejuvenating Watersheds for Agricultural Resilience (REWARD)',
        'description': 'Science-based participatory watershed management in Karnataka and Odisha',
        'benefits': 'The scheme provides comprehensive support including world bank assisted. Furthermore, it offers 2021-2026 implementation. Additionally, the scheme provides spatial data and technology use. Moreover, beneficiaries receive institutional strengthening.',
        'eligibility_criteria': 'The scheme is designed to benefit farmers in karnataka and odisha watershed areas.',
        'documents_required': 'Aadhaar card, Land records, Watershed registration',
        'application_link': 'https://wdc.gov.in/',
        'state_applicability': 'Karnataka, Odisha',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Sustainability',
        'required_documents': 'Aadhaar, Land records',
    },
    {
        'scheme_id': 'NICRA_001',
        'scheme_name': 'National Initiative on Climate Resilient Agriculture',
        'description': 'Promoting climate-resilient agricultural practices',
        'benefits': 'This program offers significant advantages such as research and technology demonstrations. Furthermore, it offers climate-resilient varieties. Additionally, the scheme provides risk management. Moreover, beneficiaries receive capacity building.',
        'eligibility_criteria': 'The scheme is designed to benefit all farmers. The scheme also covers especially in climate-vulnerable areas.',
        'documents_required': 'Aadhaar card, Land records',
        'application_link': 'https://www.indiascienceandtechnology.gov.in/research/national-initiative-climate-resilient-agriculture?field_area_id=All',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Sustainability',
        'required_documents': 'Aadhaar, Land records',
    },
    {
        'scheme_id': 'NAFCC_001',
        'scheme_name': 'National Adaptation Fund for Climate Change',
        'description': 'Climate change adaptation projects in agriculture',
        'benefits': 'Key benefits of this initiative include fund for adaptation projects. Furthermore, it offers support for vulnerable communities. Additionally, the scheme provides state and ut implementation.',
        'eligibility_criteria': 'The scheme is designed to benefit state governments. The scheme also covers vulnerable farming communities.',
        'documents_required': 'As per state project guidelines',
        'application_link': 'https://www.nabard.org/',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Sustainability',
        'required_documents': 'As per state norms',
    },
    {
        'scheme_id': 'BPKP_001',
        'scheme_name': 'Bharatiya Prakritik Krishi Paddhati',
        'description': 'Natural farming based on traditional Indian practices',
        'benefits': 'This program offers significant advantages such as sub-scheme under pkvy. Furthermore, it offers chemical-free farming. Additionally, the scheme provides traditional methods promotion. Moreover, beneficiaries receive certification support.',
        'eligibility_criteria': 'The scheme is designed to benefit farmers adopting natural farming.',
        'documents_required': 'Aadhaar card, Bank account, Land records',
        'application_link': 'https://naturalfarming.dac.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal',
        'scheme_type': 'Organic',
        'required_documents': 'Aadhaar, Land records',
    },
    {
        'scheme_id': 'CARBON_AGR_001',
        'scheme_name': 'Carbon Farming & Climate Smart Agriculture',
        'description': 'Promoting carbon sequestration and emission reduction in farming',
        'benefits': 'This program offers significant advantages such as agroforestry support. Furthermore, it offers soil carbon improvement. Additionally, the scheme provides reduced emission practices. Moreover, beneficiaries receive carbon credit opportunities.',
        'eligibility_criteria': 'The scheme is designed to benefit farmers adopting climate-smart practices.',
        'documents_required': 'Aadhaar card, Land records, Adoption certificate',
        'application_link': 'https://agricoop.nic.in/',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Sustainability',
        'required_documents': 'Aadhaar, Adoption certificate',
    },
    {
        'scheme_id': 'MFP_001',
        'scheme_name': 'Mega Food Parks Scheme',
        'description': 'Cluster-based food processing infrastructure',
        'benefits': 'The scheme provides comprehensive support including 252. Furthermore, it offers 200 mt dry warehouses. Additionally, the scheme provides 58. Moreover, beneficiaries receive 500 mt silos. It also aims to ensure 97, and 610 mt cold storage, and iqf capacity, and processing infrastructure.',
        'eligibility_criteria': 'Applicants must fall under the category of food processors. The scheme also covers fpos. It is applicable to entrepreneurs in notified food parks.',
        'documents_required': 'Registration in food park, Project proposal, Financial documents',
        'application_link': 'https://pmfme.mofpi.gov.in/pmfme/#/Login',
        'state_applicability': 'All States',
        'crop_types': 'All Crops - Processing',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Infrastructure',
        'required_documents': 'Registration, Project proposal',
    },
    {
        'scheme_id': 'AGRO_CLUSTER_001',
        'scheme_name': 'Agro Processing Clusters Scheme',
        'description': 'Creation of clusters for agro-processing',
        'benefits': 'Under this scheme, beneficiaries are entitled to modern infrastructure. Furthermore, it offers common facilities. Additionally, the scheme provides market linkage. Moreover, beneficiaries receive technical support.',
        'eligibility_criteria': 'Eligibility for this program is extended to farmer groups. The scheme also covers fpos. It is applicable to processors in cluster areas.',
        'documents_required': 'Cluster membership, Project report, Registration documents',
        'application_link': 'https://www.mofpi.gov.in/en/Schemes/agro-processing-cluster',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Infrastructure',
        'required_documents': 'Cluster membership, Project docs',
    },
    {
        'scheme_id': 'PMFME_001',
        'scheme_name': 'PM Formalization of Micro Food Processing Enterprises (PMFME)',
        'description': 'Support for micro food processing enterprises',
        'benefits': 'This program offers significant advantages such as credit-linked subsidy. Furthermore, it offers training. Additionally, the scheme provides market access. Moreover, beneficiaries receive common infrastructure.',
        'eligibility_criteria': 'Applicants must fall under the category of micro food processing enterprises. The scheme also covers individual entrepreneurs. It is applicable to fpos. Furthermore, eligibility extends to shgs. Additionally, it includes cooperatives.',
        'documents_required': 'Aadhaar card, Enterprise registration, Bank account, Project proposal',
        'application_link': 'https://www.mofpi.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'All Crops - Processing',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Financial Support',
        'required_documents': 'Aadhaar, Enterprise registration, Project',
    },
    {
        'scheme_id': 'NSC_001',
        'scheme_name': 'National Seeds Corporation - Quality Seeds',
        'description': 'Certified seed distribution and production',
        'benefits': 'Key benefits of this initiative include quality certified seeds. Furthermore, it offers foundation and certified seed production. Additionally, the scheme provides breeder seed multiplication.',
        'eligibility_criteria': 'Eligibility for this program is extended to registered seed growers. The scheme also covers farmers.',
        'documents_required': 'Seed grower registration, Land records, Aadhaar card',
        'application_link': 'https://www.indiaseeds.com/',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Production',
        'required_documents': 'Registration, Land records',
    },
    {
        'scheme_id': 'SEED_VILLAGE_001',
        'scheme_name': 'Seed Village Program',
        'description': 'Village-level quality seed production',
        'benefits': 'Key benefits of this initiative include technical support. Furthermore, it offers seed certification. Additionally, the scheme provides market linkage. Moreover, beneficiaries receive price premium.',
        'eligibility_criteria': 'Eligibility for this program is extended to farmers in seed villages.',
        'documents_required': 'Aadhaar card, Land records, Seed village membership',
        'application_link': 'https://seednet.gov.in/',
        'state_applicability': 'All States',
        'crop_types': 'All Crops',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Production',
        'required_documents': 'Aadhaar, Land records, Membership',
    },
    {
        'scheme_id': 'TMC_001',
        'scheme_name': 'Technology Mission on Cotton',
        'description': 'Productivity and quality improvement in cotton',
        'benefits': 'This program offers significant advantages such as mini mission i: technology. Furthermore, it offers mini mission ii: production. Additionally, the scheme provides mini mission iii: processing. Moreover, beneficiaries receive mini mission iv: marketing.',
        'eligibility_criteria': 'Applicants must fall under the category of cotton farmers.',
        'documents_required': 'Aadhaar card, Land records, Cotton cultivation proof',
        'application_link': 'https://ecotton.dac.gov.in/',
        'state_applicability': 'Punjab, Haryana, Rajasthan, Madhya Pradesh, Gujarat, Maharashtra, Telangana, Andhra Pradesh, Karnataka, Tamil Nadu, Odisha',
        'crop_types': 'Cotton',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Production',
        'required_documents': 'Aadhaar, Land records',
    },
    {
        'scheme_id': 'JUTE_TECH_001',
        'scheme_name': 'Jute Technology Mission',
        'description': 'Modernization and diversification of jute sector',
        'benefits': 'The scheme provides comprehensive support including quality seed distribution. Furthermore, it offers technology upgradation. Additionally, the scheme provides machinery support. Moreover, beneficiaries receive market development.',
        'eligibility_criteria': 'This scheme is primarily targeted at jute farmers. The scheme also covers jute mills.',
        'documents_required': 'Aadhaar card, Land records, Jute cultivation area',
        'application_link': 'https://trace-textiles.gov.in/sign-up',
        'state_applicability': 'West Bengal, Bihar, Assam, Odisha, Andhra Pradesh, Tripura, Meghalaya',
        'crop_types': 'Jute',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Production',
        'required_documents': 'Aadhaar, Land records',
    },
    {
        'scheme_id': 'GOA_HORT_001',
        'scheme_name': 'Goa State Horticulture Assistance',
        'description': 'Financial assistance for cashew and coconut plantation maintenance in Goa.',
        'benefits': 'Subsidy for inputs, technical support',
        'eligibility_criteria': 'Farmers with documented land ownership in Goa',
        'documents_required': 'Krishi Card, Aadhaar, Land documents',
        'application_link': 'https://agri.goa.gov.in/',
        'state_applicability': 'Goa',
        'crop_types': 'Cashew, Coconut',
        'farmer_category': 'Small,Marginal,Large',
        'scheme_type': 'Financial Support',
        'required_documents': 'Krishi Card, Aadhaar, Land docs',
    }
]

# Create DataFrame
schemes_df = pd.DataFrame(schemes_data)

# Define absolute path to save location
save_dir = r'C:\Users\KIIT\Desktop\AgriShield\data\processed'
os.makedirs(save_dir, exist_ok=True)

# Define filename and full path
csv_filename = 'government_schemes.csv'
csv_filepath = os.path.join(save_dir, csv_filename)

# Save to CSV
schemes_df.to_csv(csv_filepath, index=False, encoding='utf-8')

# Display summary
print(f'✅ Successfully saved {len(schemes_df)} schemes')
print(f'\n📊 Dataset Summary:')
print(f'   - Total schemes: {len(schemes_df)}')
print(f'   - Columns: {len(schemes_df.columns)}')
print(f'   - States covered: {schemes_df["state_applicability"].nunique()}')
print(f'   - Scheme types: {schemes_df["scheme_type"].nunique()}')
print(f'   - Saved to: {csv_filepath}')
